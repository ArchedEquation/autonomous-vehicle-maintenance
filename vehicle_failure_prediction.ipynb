# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, models
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
import pickle
import json
# Out:
# WARNING:tensorflow:From c:\Users\msaya\Miniconda3\envs\ey2\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
def generate_synthetic_data(num_samples=10000):
    """Generate synthetic vehicle telematics with stronger feature correlations"""
    
    print(f"\n[INFO] Generating {num_samples} synthetic samples with enhanced correlations...")
    
    components = ['engine', 'transmission', 'brakes', 'battery', 'cooling_system']
    severities = ['low', 'medium', 'high', 'critical']
    
    data = []
    
    for i in range(num_samples):
        # Select component that will fail
        failing_component = np.random.choice(components)
        component_index = components.index(failing_component)
        
        # Generate time to failure with more variation
        time_to_failure = np.random.beta(2, 5) * 365  # More samples near failure
        
        # Stronger health factor correlation
        health_factor = max(0, 1 - (time_to_failure / 365))
        health_squared = health_factor ** 2  # Non-linear degradation
        
        # Base noise
        noise = lambda scale=1.0: np.random.normal(0, 0.05 * scale)
        
        # Component-specific feature generation with stronger signals
        if failing_component == 'engine':
            engine_degradation = health_squared * 50 + noise(10)
            rpm_variance = health_squared * 1500 + noise(200)
            oil_drop = health_squared * 30 + noise(5)
            vibration_increase = health_squared * 12 + noise(2)
            emission_increase = health_squared * 120 + noise(20)
        else:
            engine_degradation = noise(5)
            rpm_variance = noise(100)
            oil_drop = noise(2)
            vibration_increase = noise(1)
            emission_increase = noise(10)
        
        if failing_component == 'transmission':
            trans_vibration = health_squared * 15 + noise(2)
            acceleration_issue = health_squared * 8 + noise(1)
        else:
            trans_vibration = noise(1)
            acceleration_issue = noise(0.5)
        
        if failing_component == 'brakes':
            brake_degradation = health_squared * 10 + noise(1)
            noise_increase = health_squared * 30 + noise(5)
        else:
            brake_degradation = noise(0.5)
            noise_increase = noise(3)
        
        if failing_component == 'battery':
            voltage_drop = health_squared * 3 + noise(0.2)
        else:
            voltage_drop = noise(0.1)
        
        if failing_component == 'cooling_system':
            coolant_drop = health_squared * 50 + noise(5)
            temp_increase = health_squared * 40 + noise(5)
        else:
            coolant_drop = noise(2)
            temp_increase = noise(3)
        
        # Generate features with stronger correlations
        sample = {
            # Telematics data
            'engine_temp': 75 + np.random.uniform(-5, 15) + engine_degradation + temp_increase,
            'rpm': 2000 + np.random.uniform(-500, 2000) + rpm_variance,
            'fuel_consumption': 7 + np.random.uniform(-1, 3) + (engine_degradation * 0.1),
            'battery_voltage': 13.5 + np.random.uniform(-0.5, 0.5) - voltage_drop,
            'oil_pressure': 45 + np.random.uniform(-10, 15) - oil_drop,
            'coolant_level': 90 + np.random.uniform(-5, 10) - coolant_drop,
            
            # Usage patterns (correlated with failure)
            'mileage': np.random.uniform(50000, 250000) + (health_factor * 100000),
            'avg_speed': 50 + np.random.uniform(-20, 30),
            'acceleration': np.random.uniform(2, 8) + acceleration_issue,
            'braking': np.random.uniform(2, 8) + brake_degradation,
            'trip_duration': np.random.uniform(20, 180),
            
            # Environmental
            'ambient_temp': np.random.uniform(-5, 40),
            'humidity': np.random.uniform(20, 90),
            'road_condition': np.random.beta(2, 2),  # More centered distribution
            
            # Historical (correlated with failure)
            'vehicle_age': np.random.uniform(1, 15) + (health_factor * 8),
            'last_maintenance_days': np.random.uniform(30, 300) + (health_factor * 200),
            'previous_failures': np.random.poisson(health_factor * 3),
            
            # Sensor readings
            'vibration': np.random.uniform(1, 5) + vibration_increase + trans_vibration,
            'noise_level': 50 + np.random.uniform(-10, 20) + noise_increase,
            'emissions': 80 + np.random.uniform(-20, 40) + emission_increase,
            
            # Outputs - with clearer severity mapping
            'component_failure': component_index,
            'time_to_failure': time_to_failure,
            'severity': int(health_factor * 3.99)  # 0-3 mapping to ensure coverage
        }
        
        data.append(sample)
    
    df = pd.DataFrame(data)
    
    # Add interaction features (feature engineering)
    df['temp_rpm_interaction'] = df['engine_temp'] * df['rpm'] / 10000
    df['age_mileage_ratio'] = df['vehicle_age'] / (df['mileage'] / 10000 + 1)
    df['maintenance_mileage'] = df['last_maintenance_days'] * df['mileage'] / 100000
    df['vibration_noise'] = df['vibration'] * df['noise_level'] / 100
    
    print(f"[SUCCESS] Generated {len(df)} samples with {len(df.columns)} features")
    
    return df

# Generate more data
df = generate_synthetic_data(10000)

# Save raw data
df.to_csv('data/vehicle_failure_data.csv', index=False)
print(f"[SUCCESS] Saved raw data to 'data/vehicle_failure_data.csv'")
# Out:
# [INFO] Generating 10000 synthetic samples with enhanced correlations...
# [SUCCESS] Generated 10000 samples with 27 features
# [SUCCESS] Saved raw data to 'data/vehicle_failure_data.csv'

# %%
print("\n[INFO] Preprocessing data...")

# Separate features and targets
feature_columns = [
    'engine_temp', 'rpm', 'fuel_consumption', 'battery_voltage', 'oil_pressure', 'coolant_level',
    'mileage', 'avg_speed', 'acceleration', 'braking', 'trip_duration',
    'ambient_temp', 'humidity', 'road_condition',
    'vehicle_age', 'last_maintenance_days', 'previous_failures',
    'vibration', 'noise_level', 'emissions',
    'temp_rpm_interaction', 'age_mileage_ratio', 'maintenance_mileage', 'vibration_noise'
]

X = df[feature_columns].values
y_component = df['component_failure'].values
y_time = df['time_to_failure'].values / 365.0  # Normalize to 0-1
y_severity = df['severity'].values

# Standardize features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Save scaler
with open('scaler.pkl', 'wb') as f:
    pickle.dump(scaler, f)
print("[SUCCESS] Saved scaler to 'scaler.pkl'")
# Out:
# [INFO] Preprocessing data...
# [SUCCESS] Saved scaler to 'scaler.pkl'

# %%
def create_sequences(X, y_comp, y_time, y_sev, seq_length=15):
    """Create sequences for LSTM input"""
    
    print(f"[INFO] Creating sequences with length {seq_length}...")
    
    X_seq, y_comp_seq, y_time_seq, y_sev_seq = [], [], [], []
    
    for i in range(len(X) - seq_length):
        X_seq.append(X[i:i+seq_length])
        y_comp_seq.append(y_comp[i+seq_length-1])
        y_time_seq.append(y_time[i+seq_length-1])
        y_sev_seq.append(y_sev[i+seq_length-1])
    
    return (
        np.array(X_seq),
        np.array(y_comp_seq),
        np.array(y_time_seq),
        np.array(y_sev_seq)
    )

sequence_length = 15  # Longer sequences for better pattern recognition
X_sequences, y_comp_seq, y_time_seq, y_sev_seq = create_sequences(
    X_scaled, y_component, y_time, y_severity, sequence_length
)

print(f"[SUCCESS] Created {len(X_sequences)} sequences")
print(f"[INFO] Sequence shape: {X_sequences.shape}")
# Out:
# [INFO] Creating sequences with length 15...
# [SUCCESS] Created 9985 sequences
# [INFO] Sequence shape: (9985, 15, 24)

# %%
X_train, X_test, y_comp_train, y_comp_test, y_time_train, y_time_test, y_sev_train, y_sev_test = train_test_split(
    X_sequences, y_comp_seq, y_time_seq, y_sev_seq,
    test_size=0.15,  # Slightly smaller test set for more training data
    random_state=42,
    stratify=y_comp_seq  # Stratify by component
)

print(f"\n[INFO] Train set: {len(X_train)} samples")
print(f"[INFO] Test set: {len(X_test)} samples")
# Out:
# [INFO] Train set: 8487 samples
# [INFO] Test set: 1498 samples

# %%
print("\n[INFO] Building optimized LSTM model architecture...")

def build_optimized_lstm(input_shape, num_components=5, num_severities=4):
    """Build deeper, more powerful LSTM model"""
    
    # Input layer
    inputs = layers.Input(shape=input_shape, name='input')
    
    # Bidirectional LSTM layers for better context
    x = layers.Bidirectional(layers.LSTM(256, return_sequences=True))(inputs)
    x = layers.BatchNormalization()(x)
    x = layers.Dropout(0.4)(x)
    
    x = layers.Bidirectional(layers.LSTM(128, return_sequences=True))(x)
    x = layers.BatchNormalization()(x)
    x = layers.Dropout(0.4)(x)
    
    x = layers.LSTM(64, return_sequences=False)(x)
    x = layers.BatchNormalization()(x)
    x = layers.Dropout(0.3)(x)
    
    # Shared dense layers
    x = layers.Dense(128, activation='relu')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Dropout(0.3)(x)
    
    x = layers.Dense(64, activation='relu')(x)
    x = layers.Dropout(0.2)(x)
    
    # Task-specific heads with additional layers
    # Component failure head
    comp_x = layers.Dense(32, activation='relu', name='comp_dense')(x)
    component_output = layers.Dense(num_components, activation='softmax', name='component_failure')(comp_x)
    
    # Time to failure head
    time_x = layers.Dense(32, activation='relu', name='time_dense')(x)
    time_output = layers.Dense(1, activation='sigmoid', name='time_to_failure')(time_x)
    
    # Severity head
    sev_x = layers.Dense(32, activation='relu', name='sev_dense')(x)
    severity_output = layers.Dense(num_severities, activation='softmax', name='severity')(sev_x)
    
    # Create model
    model = models.Model(
        inputs=inputs,
        outputs=[component_output, time_output, severity_output]
    )
    
    return model
# Out:
# [INFO] Building optimized LSTM model architecture...

# %%
input_shape = (sequence_length, len(feature_columns))
model = build_optimized_lstm(input_shape)
# Out:
# WARNING:tensorflow:From c:\Users\msaya\Miniconda3\envs\ey2\lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.

# %%
model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=0.0005),  # Lower learning rate
    loss={
        'component_failure': 'sparse_categorical_crossentropy',
        'time_to_failure': 'mse',
        'severity': 'sparse_categorical_crossentropy'
    },
    loss_weights={
        'component_failure': 1.2,  # Increased weight
        'time_to_failure': 0.3,    # Decreased weight (regression is easier)
        'severity': 1.0
    },
    metrics={
        'component_failure': ['accuracy'],
        'time_to_failure': ['mae'],
        'severity': ['accuracy']
    }
)

print("[SUCCESS] Model architecture built")
print(f"[INFO] Total parameters: {model.count_params():,}")
model.summary()
# Out:
# [SUCCESS] Model architecture built
# [INFO] Total parameters: 1,341,034
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input (InputLayer)          [(None, 15, 24)]             0         []
#
#  bidirectional (Bidirection  (None, 15, 512)              575488    ['input[0][0]']
#  al)
#
#  batch_normalization (Batch  (None, 15, 512)              2048      ['bidirectional[0][0]']
#  Normalization)
#
#  dropout (Dropout)           (None, 15, 512)              0         ['batch_normalization[0][0]']
#
#  bidirectional_1 (Bidirecti  (None, 15, 256)              656384    ['dropout[0][0]']
#  onal)
#
#  batch_normalization_1 (Bat  (None, 15, 256)              1024      ['bidirectional_1[0][0]']
#  chNormalization)
#
#  dropout_1 (Dropout)         (None, 15, 256)              0         ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  lstm_2 (LSTM)               (None, 64)                   82176     ['dropout_1[0][0]']
#
#  batch_normalization_2 (Bat  (None, 64)                   256       ['lstm_2[0][0]']
#  chNormalization)
#
#  dropout_2 (Dropout)         (None, 64)                   0         ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  dense (Dense)               (None, 128)                  8320      ['dropout_2[0][0]']
#
#  batch_normalization_3 (Bat  (None, 128)                  512       ['dense[0][0]']
#  chNormalization)
#
#  dropout_3 (Dropout)         (None, 128)                  0         ['batch_normalization_3[0][0]'
#                                                                     ]
#
#  dense_1 (Dense)             (None, 64)                   8256      ['dropout_3[0][0]']
#
#  dropout_4 (Dropout)         (None, 64)                   0         ['dense_1[0][0]']
#
#  comp_dense (Dense)          (None, 32)                   2080      ['dropout_4[0][0]']
#
#  time_dense (Dense)          (None, 32)                   2080      ['dropout_4[0][0]']
#
#  sev_dense (Dense)           (None, 32)                   2080      ['dropout_4[0][0]']
#
#  component_failure (Dense)   (None, 5)                    165       ['comp_dense[0][0]']
#
#  time_to_failure (Dense)     (None, 1)                    33        ['time_dense[0][0]']
#
#  severity (Dense)            (None, 4)                    132       ['sev_dense[0][0]']
#
# ==================================================================================================
# Total params: 1341034 (5.12 MB)
# Trainable params: 1339114 (5.11 MB)
# Non-trainable params: 1920 (7.50 KB)
# __________________________________________________________________________________________________

# %%
print("\n[INFO] Starting model training...")

callbacks = [
    EarlyStopping(
        monitor='val_loss',
        patience=20,  # More patience
        restore_best_weights=True,
        verbose=1
    ),
    ReduceLROnPlateau(
        monitor='val_loss',
        factor=0.5,
        patience=8,
        min_lr=1e-7,
        verbose=1
    ),
    ModelCheckpoint(
        'best_model.keras',
        monitor='val_loss',
        save_best_only=True,
        verbose=1
    )
]

# Train model with more epochs
history = model.fit(
    X_train,
    {
        'component_failure': y_comp_train,
        'time_to_failure': y_time_train,
        'severity': y_sev_train
    },
    validation_data=(
        X_test,
        {
            'component_failure': y_comp_test,
            'time_to_failure': y_time_test,
            'severity': y_sev_test
        }
    ),
    epochs=100,  # More epochs
    batch_size=64,  # Larger batch size
    callbacks=callbacks,
    verbose=1
)

print("\n[SUCCESS] Training completed!")

print("\n[SUCCESS] Training completed!")
# Out:
# [INFO] Starting model training...
# Epoch 1/100
# WARNING:tensorflow:From c:\Users\msaya\Miniconda3\envs\ey2\lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# WARNING:tensorflow:From c:\Users\msaya\Miniconda3\envs\ey2\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# 132/133 [============================>.] - ETA: 0s - loss: 3.0160 - component_failure_loss: 1.5462 - time_to_failure_loss: 0.0413 - severity_loss: 1.1481 - component_failure_accuracy: 0.3451 - time_to_failure_mae: 0.1603 - severity_accuracy: 0.4450
# Epoch 1: val_loss improved from inf to 2.83283, saving model to best_model.keras
# 133/133 [==============================] - 15s 68ms/step - loss: 3.0156 - component_failure_loss: 1.5463 - time_to_failure_loss: 0.0413 - severity_loss: 1.1477 - component_failure_accuracy: 0.3454 - time_to_failure_mae: 0.1603 - severity_accuracy: 0.4452 - val_loss: 2.8328 - val_component_failure_loss: 1.4319 - val_time_to_failure_loss: 0.0429 - val_severity_loss: 1.1017 - val_component_failure_accuracy: 0.4907 - val_time_to_failure_mae: 0.1763 - val_severity_accuracy: 0.4693 - lr: 5.0000e-04
# Epoch 2/100
# 132/133 [============================>.] - ETA: 0s - loss: 2.2004 - component_failure_loss: 0.9932 - time_to_failure_loss: 0.0285 - severity_loss: 1.0000 - component_failure_accuracy: 0.6223 - time_to_failure_mae: 0.1340 - severity_accuracy: 0.4805
# Epoch 2: val_loss improved from 2.83283 to 1.82122, saving model to best_model.keras
# 133/133 [==============================] - 7s 55ms/step - loss: 2.2010 - component_failure_loss: 0.9929 - time_to_failure_loss: 0.0286 - severity_loss: 1.0010 - component_failure_accuracy: 0.6226 - time_to_failure_mae: 0.1340 - severity_accuracy: 0.4797 - val_loss: 1.8212 - val_component_failure_loss: 0.7291 - val_time_to_failure_loss: 0.0226 - val_severity_loss: 0.9396 - val_component_failure_accuracy: 0.7503 - val_time_to_failure_mae: 0.1244 - val_severity_accuracy: 0.5340 - lr: 5.0000e-04
# Epoch 3/100
# 132/133 [============================>.] - ETA: 0s - loss: 1.4530 - component_failure_loss: 0.4663 - time_to_failure_loss: 0.0207 - severity_loss: 0.8872 - component_failure_accuracy: 0.8458 - time_to_failure_mae: 0.1136 - severity_accuracy: 0.5452
# Epoch 3: val_loss improved from 1.82122 to 1.00932, saving model to best_model.keras
# 133/133 [==============================] - 7s 55ms/step - loss: 1.4525 - component_failure_loss: 0.4663 - time_to_failure_loss: 0.0207 - severity_loss: 0.8868 - component_failure_accuracy: 0.8458 - time_to_failure_mae: 0.1136 - severity_accuracy: 0.5459 - val_loss: 1.0093 - val_component_failure_loss: 0.2276 - val_time_to_failure_loss: 0.0107 - val_severity_loss: 0.7330 - val_component_failure_accuracy: 0.9259 - val_time_to_failure_mae: 0.0836 - val_severity_accuracy: 0.6702 - lr: 5.0000e-04
# Epoch 4/100
# 132/133 [============================>.] - ETA: 0s - loss: 1.1200 - component_failure_loss: 0.2919 - time_to_failure_loss: 0.0157 - severity_loss: 0.7650 - component_failure_accuracy: 0.9033 - time_to_failure_mae: 0.0985 - severity_accuracy: 0.6267
# Epoch 4: val_loss improved from 1.00932 to 0.77425, saving model to best_model.keras
# 133/133 [==============================] - 8s 57ms/step - loss: 1.1189 - component_failure_loss: 0.2916 - time_to_failure_loss: 0.0157 - severity_loss: 0.7642 - component_failure_accuracy: 0.9033 - time_to_failure_mae: 0.0984 - severity_accuracy: 0.6271 - val_loss: 0.7743 - val_component_failure_loss: 0.1524 - val_time_to_failure_loss: 0.0073 - val_severity_loss: 0.5892 - val_component_failure_accuracy: 0.9433 - val_time_to_failure_mae: 0.0667 - val_severity_accuracy: 0.7263 - lr: 5.0000e-04
# Epoch 5/100
# 132/133 [============================>.] - ETA: 0s - loss: 1.0103 - component_failure_loss: 0.2547 - time_to_failure_loss: 0.0135 - severity_loss: 0.7006 - component_failure_accuracy: 0.9134 - time_to_failure_mae: 0.0915 - severity_accuracy: 0.6658
# Epoch 5: val_loss improved from 0.77425 to 0.69737, saving model to best_model.keras
# 133/133 [==============================] - 7s 55ms/step - loss: 1.0108 - component_failure_loss: 0.2545 - time_to_failure_loss: 0.0135 - severity_loss: 0.7013 - component_failure_accuracy: 0.9133 - time_to_failure_mae: 0.0914 - severity_accuracy: 0.6655 - val_loss: 0.6974 - val_component_failure_loss: 0.1358 - val_time_to_failure_loss: 0.0061 - val_severity_loss: 0.5325 - val_component_failure_accuracy: 0.9539 - val_time_to_failure_mae: 0.0621 - val_severity_accuracy: 0.7637 - lr: 5.0000e-04
# Epoch 6/100
# 132/133 [============================>.] - ETA: 0s - loss: 0.9316 - component_failure_loss: 0.2229 - time_to_failure_loss: 0.0120 - severity_loss: 0.6605 - component_failure_accuracy: 0.9218 - time_to_failure_mae: 0.0864 - severity_accuracy: 0.6973
# Epoch 6: val_loss improved from 0.69737 to 0.65695, saving model to best_model.keras
# 133/133 [==============================] - 7s 55ms/step - loss: 0.9312 - component_failure_loss: 0.2230 - time_to_failure_loss: 0.0120 - severity_loss: 0.6600 - component_failure_accuracy: 0.9219 - time_to_failure_mae: 0.0863 - severity_accuracy: 0.6974 - val_loss: 0.6570 - val_component_failure_loss: 0.1246 - val_time_to_failure_loss: 0.0060 - val_severity_loss: 0.5056 - val_component_failure_accuracy: 0.9566 - val_time_to_failure_mae: 0.0602 - val_severity_accuracy: 0.7737 - lr: 5.0000e-04
# Epoch 7/100
# 132/133 [============================>.] - ETA: 0s - loss: 0.8872 - component_failure_loss: 0.2095 - time_to_failure_loss: 0.0113 - severity_loss: 0.6324 - component_failure_accuracy: 0.9295 - time_to_failure_mae: 0.0840 - severity_accuracy: 0.7107
# Epoch 7: val_loss improved from 0.65695 to 0.61609, saving model to best_model.keras
# 133/133 [==============================] - 7s 54ms/step - loss: 0.8867 - component_failure_loss: 0.2090 - time_to_failure_loss: 0.0113 - severity_loss: 0.6325 - component_failure_accuracy: 0.9297 - time_to_failure_mae: 0.0840 - severity_accuracy: 0.7109 - val_loss: 0.6161 - val_component_failure_loss: 0.1186 - val_time_to_failure_loss: 0.0058 - val_severity_loss: 0.4721 - val_component_failure_accuracy: 0.9579 - val_time_to_failure_mae: 0.0603 - val_severity_accuracy: 0.7884 - lr: 5.0000e-04
# Epoch 8/100
# 132/133 [============================>.] - ETA: 0s - loss: 0.8435 - component_failure_loss: 0.1947 - time_to_failure_loss: 0.0105 - severity_loss: 0.6067 - component_failure_accuracy: 0.9312 - time_to_failure_mae: 0.0806 - severity_accuracy: 0.7221
# Epoch 8: val_loss improved from 0.61609 to 0.59291, saving model to best_model.keras
# 133/133 [==============================] - 7s 56ms/step - loss: 0.8431 - component_failure_loss: 0.1944 - time_to_failure_loss: 0.0105 - severity_loss: 0.6067 - component_failure_accuracy: 0.9314 - time_to_failure_mae: 0.0806 - severity_accuracy: 0.7222 - val_loss: 0.5929 - val_component_failure_loss: 0.1102 - val_time_to_failure_loss: 0.0058 - val_severity_loss: 0.4589 - val_component_failure_accuracy: 0.9666 - val_time_to_failure_mae: 0.0612 - val_severity_accuracy: 0.7911 - lr: 5.0000e-04
# Epoch 9/100
# 132/133 [============================>.] - ETA: 0s - loss: 0.7979 - component_failure_loss: 0.1732 - time_to_failure_loss: 0.0101 - severity_loss: 0.5870 - component_failure_accuracy: 0.9415 - time_to_failure_mae: 0.0796 - severity_accuracy: 0.7402
# Epoch 9: val_loss improved from 0.59291 to 0.57757, saving model to best_model.keras
# 133/133 [==============================] - 7s 53ms/step - loss: 0.7977 - component_failure_loss: 0.1730 - time_to_failure_loss: 0.0101 - severity_loss: 0.5870 - component_failure_accuracy: 0.9417 - time_to_failure_mae: 0.0796 - severity_accuracy: 0.7402 - val_loss: 0.5776 - val_component_failure_loss: 0.1081 - val_time_to_failure_loss: 0.0052 - val_severity_loss: 0.4463 - val_component_failure_accuracy: 0.9599 - val_time_to_failure_mae: 0.0570 - val_severity_accuracy: 0.8011 - lr: 5.0000e-04
# Epoch 10/100
# 132/133 [============================>.] - ETA: 0s - loss: 0.7906 - component_failure_loss: 0.1800 - time_to_failure_loss: 0.0097 - severity_loss: 0.5716 - component_failure_accuracy: 0.9369 - time_to_failure_mae: 0.0776 - severity_accuracy: 0.7494
# Epoch 10: val_loss did not improve from 0.57757
# 133/133 [==============================] - 7s 52ms/step - loss: 0.7903 - component_failure_loss: 0.1803 - time_to_failure_loss: 0.0097 - severity_loss: 0.5710 - component_failure_accuracy: 0.9367 - time_to_failure_mae: 0.0775 - severity_accuracy: 0.7496 - val_loss: 0.5929 - val_component_failure_loss: 0.1131 - val_time_to_failure_loss: 0.0056 - val_severity_loss: 0.4555 - val_component_failure_accuracy: 0.9579 - val_time_to_failure_mae: 0.0597 - val_severity_accuracy: 0.7944 - lr: 5.0000e-04
# Epoch 11/100
# 132/133 [============================>.] - ETA: 0s - loss: 0.7529 - component_failure_loss: 0.1602 - time_to_failure_loss: 0.0091 - severity_loss: 0.5580 - component_failure_accuracy: 0.9467 - time_to_failure_mae: 0.0751 - severity_accuracy: 0.7487
# Epoch 11: val_loss did not improve from 0.57757
# 133/133 [==============================] - 7s 50ms/step - loss: 0.7530 - component_failure_loss: 0.1603 - time_to_failure_loss: 0.0091 - severity_loss: 0.5580 - component_failure_accuracy: 0.9465 - time_to_failure_mae: 0.0752 - severity_accuracy: 0.7489 - val_loss: 0.5862 - val_component_failure_loss: 0.1101 - val_time_to_failure_loss: 0.0053 - val_severity_loss: 0.4525 - val_component_failure_accuracy: 0.9619 - val_time_to_failure_mae: 0.0558 - val_severity_accuracy: 0.8044 - lr: 5.0000e-04
# Epoch 12/100
# 132/133 [============================>.] - ETA: 0s - loss: 0.7412 - component_failure_loss: 0.1654 - time_to_failure_loss: 0.0090 - severity_loss: 0.5400 - component_failure_accuracy: 0.9434 - time_to_failure_mae: 0.0749 - severity_accuracy: 0.7628
# Epoch 12: val_loss improved from 0.57757 to 0.56530, saving model to best_model.keras
# 133/133 [==============================] - 7s 53ms/step - loss: 0.7423 - component_failure_loss: 0.1661 - time_to_failure_loss: 0.0090 - severity_loss: 0.5402 - component_failure_accuracy: 0.9431 - time_to_failure_mae: 0.0749 - severity_accuracy: 0.7625 - val_loss: 0.5653 - val_component_failure_loss: 0.1063 - val_time_to_failure_loss: 0.0051 - val_severity_loss: 0.4362 - val_component_failure_accuracy: 0.9633 - val_time_to_failure_mae: 0.0556 - val_severity_accuracy: 0.8151 - lr: 5.0000e-04
# Epoch 13/100
# 132/133 [============================>.] - ETA: 0s - loss: 0.7224 - component_failure_loss: 0.1564 - time_to_failure_loss: 0.0088 - severity_loss: 0.5321 - component_failure_accuracy: 0.9461 - time_to_failure_mae: 0.0734 - severity_accuracy: 0.7711
# Epoch 13: val_loss improved from 0.56530 to 0.55896, saving model to best_model.keras
# 133/133 [==============================] - 7s 52ms/step - loss: 0.7216 - component_failure_loss: 0.1559 - time_to_failure_loss: 0.0088 - severity_loss: 0.5318 - component_failure_accuracy: 0.9463 - time_to_failure_mae: 0.0734 - severity_accuracy: 0.7708 - val_loss: 0.5590 - val_component_failure_loss: 0.1082 - val_time_to_failure_loss: 0.0051 - val_severity_loss: 0.4277 - val_component_failure_accuracy: 0.9613 - val_time_to_failure_mae: 0.0563 - val_severity_accuracy: 0.8124 - lr: 5.0000e-04
# Epoch 14/100
# 132/133 [============================>.] - ETA: 0s - loss: 0.6985 - component_failure_loss: 0.1524 - time_to_failure_loss: 0.0083 - severity_loss: 0.5130 - component_failure_accuracy: 0.9496 - time_to_failure_mae: 0.0712 - severity_accuracy: 0.7801
# Epoch 14: val_loss improved from 0.55896 to 0.55126, saving model to best_model.keras
# 133/133 [==============================] - 7s 52ms/step - loss: 0.6988 - component_failure_loss: 0.1523 - time_to_failure_loss: 0.0083 - severity_loss: 0.5136 - component_failure_accuracy: 0.9497 - time_to_failure_mae: 0.0713 - severity_accuracy: 0.7799 - val_loss: 0.5513 - val_component_failure_loss: 0.1056 - val_time_to_failure_loss: 0.0052 - val_severity_loss: 0.4230 - val_component_failure_accuracy: 0.9666 - val_time_to_failure_mae: 0.0560 - val_severity_accuracy: 0.8124 - lr: 5.0000e-04
# Epoch 15/100
# 133/133 [==============================] - ETA: 0s - loss: 0.6936 - component_failure_loss: 0.1493 - time_to_failure_loss: 0.0082 - severity_loss: 0.5120 - component_failure_accuracy: 0.9491 - time_to_failure_mae: 0.0715 - severity_accuracy: 0.7812
# Epoch 15: val_loss did not improve from 0.55126
# 133/133 [==============================] - 7s 51ms/step - loss: 0.6936 - component_failure_loss: 0.1493 - time_to_failure_loss: 0.0082 - severity_loss: 0.5120 - component_failure_accuracy: 0.9491 - time_to_failure_mae: 0.0715 - severity_accuracy: 0.7812 - val_loss: 0.5639 - val_component_failure_loss: 0.1085 - val_time_to_failure_loss: 0.0054 - val_severity_loss: 0.4321 - val_component_failure_accuracy: 0.9586 - val_time_to_failure_mae: 0.0586 - val_severity_accuracy: 0.8011 - lr: 5.0000e-04
# Epoch 16/100
# 132/133 [============================>.] - ETA: 0s - loss: 0.6888 - component_failure_loss: 0.1466 - time_to_failure_loss: 0.0081 - severity_loss: 0.5105 - component_failure_accuracy: 0.9498 - time_to_failure_mae: 0.0706 - severity_accuracy: 0.7842
# Epoch 16: val_loss did not improve from 0.55126
# 133/133 [==============================] - 7s 50ms/step - loss: 0.6899 - component_failure_loss: 0.1469 - time_to_failure_loss: 0.0081 - severity_loss: 0.5112 - component_failure_accuracy: 0.9497 - time_to_failure_mae: 0.0707 - severity_accuracy: 0.7838 - val_loss: 0.5708 - val_component_failure_loss: 0.1197 - val_time_to_failure_loss: 0.0053 - val_severity_loss: 0.4255 - val_component_failure_accuracy: 0.9553 - val_time_to_failure_mae: 0.0578 - val_severity_accuracy: 0.8111 - lr: 5.0000e-04
# Epoch 17/100
# 133/133 [==============================] - ETA: 0s - loss: 0.6658 - component_failure_loss: 0.1324 - time_to_failure_loss: 0.0080 - severity_loss: 0.5044 - component_failure_accuracy: 0.9538 - time_to_failure_mae: 0.0706 - severity_accuracy: 0.7856
# Epoch 17: val_loss did not improve from 0.55126
# 133/133 [==============================] - 7s 52ms/step - loss: 0.6658 - component_failure_loss: 0.1324 - time_to_failure_loss: 0.0080 - severity_loss: 0.5044 - component_failure_accuracy: 0.9538 - time_to_failure_mae: 0.0706 - severity_accuracy: 0.7856 - val_loss: 0.5934 - val_component_failure_loss: 0.1147 - val_time_to_failure_loss: 0.0053 - val_severity_loss: 0.4541 - val_component_failure_accuracy: 0.9626 - val_time_to_failure_mae: 0.0580 - val_severity_accuracy: 0.7964 - lr: 5.0000e-04
# Epoch 18/100
# 132/133 [============================>.] - ETA: 0s - loss: 0.6585 - component_failure_loss: 0.1358 - time_to_failure_loss: 0.0079 - severity_loss: 0.4932 - component_failure_accuracy: 0.9525 - time_to_failure_mae: 0.0700 - severity_accuracy: 0.7888
# Epoch 18: val_loss did not improve from 0.55126
# 133/133 [==============================] - 7s 50ms/step - loss: 0.6577 - component_failure_loss: 0.1355 - time_to_failure_loss: 0.0079 - severity_loss: 0.4927 - component_failure_accuracy: 0.9525 - time_to_failure_mae: 0.0700 - severity_accuracy: 0.7891 - val_loss: 0.5713 - val_component_failure_loss: 0.1090 - val_time_to_failure_loss: 0.0051 - val_severity_loss: 0.4389 - val_component_failure_accuracy: 0.9640 - val_time_to_failure_mae: 0.0562 - val_severity_accuracy: 0.8044 - lr: 5.0000e-04
# Epoch 19/100
# 132/133 [============================>.] - ETA: 0s - loss: 0.6618 - component_failure_loss: 0.1361 - time_to_failure_loss: 0.0080 - severity_loss: 0.4962 - component_failure_accuracy: 0.9522 - time_to_failure_mae: 0.0702 - severity_accuracy: 0.7924
# Epoch 19: val_loss did not improve from 0.55126
# 133/133 [==============================] - 7s 50ms/step - loss: 0.6610 - component_failure_loss: 0.1360 - time_to_failure_loss: 0.0079 - severity_loss: 0.4954 - component_failure_accuracy: 0.9522 - time_to_failure_mae: 0.0701 - severity_accuracy: 0.7925 - val_loss: 0.5766 - val_component_failure_loss: 0.1141 - val_time_to_failure_loss: 0.0053 - val_severity_loss: 0.4380 - val_component_failure_accuracy: 0.9586 - val_time_to_failure_mae: 0.0576 - val_severity_accuracy: 0.7957 - lr: 5.0000e-04
# Epoch 20/100
# 133/133 [==============================] - ETA: 0s - loss: 0.6469 - component_failure_loss: 0.1345 - time_to_failure_loss: 0.0075 - severity_loss: 0.4832 - component_failure_accuracy: 0.9550 - time_to_failure_mae: 0.0682 - severity_accuracy: 0.8022
# Epoch 20: val_loss did not improve from 0.55126
# 133/133 [==============================] - 7s 50ms/step - loss: 0.6469 - component_failure_loss: 0.1345 - time_to_failure_loss: 0.0075 - severity_loss: 0.4832 - component_failure_accuracy: 0.9550 - time_to_failure_mae: 0.0682 - severity_accuracy: 0.8022 - val_loss: 0.5712 - val_component_failure_loss: 0.1122 - val_time_to_failure_loss: 0.0050 - val_severity_loss: 0.4350 - val_component_failure_accuracy: 0.9599 - val_time_to_failure_mae: 0.0557 - val_severity_accuracy: 0.8097 - lr: 5.0000e-04
# Epoch 21/100
# 132/133 [============================>.] - ETA: 0s - loss: 0.6215 - component_failure_loss: 0.1216 - time_to_failure_loss: 0.0075 - severity_loss: 0.4734 - component_failure_accuracy: 0.9590 - time_to_failure_mae: 0.0679 - severity_accuracy: 0.7987
# Epoch 21: val_loss did not improve from 0.55126
# 133/133 [==============================] - 7s 52ms/step - loss: 0.6221 - component_failure_loss: 0.1223 - time_to_failure_loss: 0.0075 - severity_loss: 0.4731 - component_failure_accuracy: 0.9589 - time_to_failure_mae: 0.0679 - severity_accuracy: 0.7989 - val_loss: 0.5703 - val_component_failure_loss: 0.1176 - val_time_to_failure_loss: 0.0052 - val_severity_loss: 0.4277 - val_component_failure_accuracy: 0.9619 - val_time_to_failure_mae: 0.0568 - val_severity_accuracy: 0.8057 - lr: 5.0000e-04
# Epoch 22/100
# 133/133 [==============================] - ETA: 0s - loss: 0.6326 - component_failure_loss: 0.1290 - time_to_failure_loss: 0.0075 - severity_loss: 0.4756 - component_failure_accuracy: 0.9572 - time_to_failure_mae: 0.0679 - severity_accuracy: 0.8038
# Epoch 22: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 22: val_loss did not improve from 0.55126
# 133/133 [==============================] - 7s 50ms/step - loss: 0.6326 - component_failure_loss: 0.1290 - time_to_failure_loss: 0.0075 - severity_loss: 0.4756 - component_failure_accuracy: 0.9572 - time_to_failure_mae: 0.0679 - severity_accuracy: 0.8038 - val_loss: 0.5876 - val_component_failure_loss: 0.1185 - val_time_to_failure_loss: 0.0052 - val_severity_loss: 0.4439 - val_component_failure_accuracy: 0.9539 - val_time_to_failure_mae: 0.0568 - val_severity_accuracy: 0.8071 - lr: 5.0000e-04
# Epoch 23/100
# 132/133 [============================>.] - ETA: 0s - loss: 0.5998 - component_failure_loss: 0.1196 - time_to_failure_loss: 0.0071 - severity_loss: 0.4542 - component_failure_accuracy: 0.9583 - time_to_failure_mae: 0.0663 - severity_accuracy: 0.8076
# Epoch 23: val_loss did not improve from 0.55126
# 133/133 [==============================] - 7s 50ms/step - loss: 0.6006 - component_failure_loss: 0.1198 - time_to_failure_loss: 0.0071 - severity_loss: 0.4546 - component_failure_accuracy: 0.9583 - time_to_failure_mae: 0.0663 - severity_accuracy: 0.8075 - val_loss: 0.5766 - val_component_failure_loss: 0.1179 - val_time_to_failure_loss: 0.0052 - val_severity_loss: 0.4335 - val_component_failure_accuracy: 0.9566 - val_time_to_failure_mae: 0.0565 - val_severity_accuracy: 0.8117 - lr: 2.5000e-04
# Epoch 24/100
# 133/133 [==============================] - ETA: 0s - loss: 0.5902 - component_failure_loss: 0.1185 - time_to_failure_loss: 0.0070 - severity_loss: 0.4460 - component_failure_accuracy: 0.9584 - time_to_failure_mae: 0.0659 - severity_accuracy: 0.8096
# Epoch 24: val_loss did not improve from 0.55126
# 133/133 [==============================] - 7s 50ms/step - loss: 0.5902 - component_failure_loss: 0.1185 - time_to_failure_loss: 0.0070 - severity_loss: 0.4460 - component_failure_accuracy: 0.9584 - time_to_failure_mae: 0.0659 - severity_accuracy: 0.8096 - val_loss: 0.5759 - val_component_failure_loss: 0.1152 - val_time_to_failure_loss: 0.0052 - val_severity_loss: 0.4361 - val_component_failure_accuracy: 0.9566 - val_time_to_failure_mae: 0.0566 - val_severity_accuracy: 0.8037 - lr: 2.5000e-04
# Epoch 25/100
# 133/133 [==============================] - ETA: 0s - loss: 0.5791 - component_failure_loss: 0.1154 - time_to_failure_loss: 0.0068 - severity_loss: 0.4386 - component_failure_accuracy: 0.9585 - time_to_failure_mae: 0.0649 - severity_accuracy: 0.8147
# Epoch 25: val_loss did not improve from 0.55126
# 133/133 [==============================] - 7s 52ms/step - loss: 0.5791 - component_failure_loss: 0.1154 - time_to_failure_loss: 0.0068 - severity_loss: 0.4386 - component_failure_accuracy: 0.9585 - time_to_failure_mae: 0.0649 - severity_accuracy: 0.8147 - val_loss: 0.5838 - val_component_failure_loss: 0.1203 - val_time_to_failure_loss: 0.0053 - val_severity_loss: 0.4379 - val_component_failure_accuracy: 0.9593 - val_time_to_failure_mae: 0.0573 - val_severity_accuracy: 0.8131 - lr: 2.5000e-04
# Epoch 26/100
# 133/133 [==============================] - ETA: 0s - loss: 0.5647 - component_failure_loss: 0.1057 - time_to_failure_loss: 0.0067 - severity_loss: 0.4358 - component_failure_accuracy: 0.9642 - time_to_failure_mae: 0.0643 - severity_accuracy: 0.8185
# Epoch 26: val_loss did not improve from 0.55126
# 133/133 [==============================] - 7s 51ms/step - loss: 0.5647 - component_failure_loss: 0.1057 - time_to_failure_loss: 0.0067 - severity_loss: 0.4358 - component_failure_accuracy: 0.9642 - time_to_failure_mae: 0.0643 - severity_accuracy: 0.8185 - val_loss: 0.5899 - val_component_failure_loss: 0.1247 - val_time_to_failure_loss: 0.0052 - val_severity_loss: 0.4388 - val_component_failure_accuracy: 0.9559 - val_time_to_failure_mae: 0.0567 - val_severity_accuracy: 0.8117 - lr: 2.5000e-04
# Epoch 27/100
# 133/133 [==============================] - ETA: 0s - loss: 0.5492 - component_failure_loss: 0.1042 - time_to_failure_loss: 0.0069 - severity_loss: 0.4220 - component_failure_accuracy: 0.9638 - time_to_failure_mae: 0.0652 - severity_accuracy: 0.8264
# Epoch 27: val_loss did not improve from 0.55126
# 133/133 [==============================] - 7s 50ms/step - loss: 0.5492 - component_failure_loss: 0.1042 - time_to_failure_loss: 0.0069 - severity_loss: 0.4220 - component_failure_accuracy: 0.9638 - time_to_failure_mae: 0.0652 - severity_accuracy: 0.8264 - val_loss: 0.6188 - val_component_failure_loss: 0.1345 - val_time_to_failure_loss: 0.0055 - val_severity_loss: 0.4557 - val_component_failure_accuracy: 0.9553 - val_time_to_failure_mae: 0.0588 - val_severity_accuracy: 0.8037 - lr: 2.5000e-04
# Epoch 28/100
# 133/133 [==============================] - ETA: 0s - loss: 0.5393 - component_failure_loss: 0.0968 - time_to_failure_loss: 0.0069 - severity_loss: 0.4210 - component_failure_accuracy: 0.9667 - time_to_failure_mae: 0.0651 - severity_accuracy: 0.8288
# Epoch 28: val_loss did not improve from 0.55126
# 133/133 [==============================] - 7s 51ms/step - loss: 0.5393 - component_failure_loss: 0.0968 - time_to_failure_loss: 0.0069 - severity_loss: 0.4210 - component_failure_accuracy: 0.9667 - time_to_failure_mae: 0.0651 - severity_accuracy: 0.8288 - val_loss: 0.6162 - val_component_failure_loss: 0.1300 - val_time_to_failure_loss: 0.0055 - val_severity_loss: 0.4585 - val_component_failure_accuracy: 0.9559 - val_time_to_failure_mae: 0.0589 - val_severity_accuracy: 0.8017 - lr: 2.5000e-04
# Epoch 29/100
# 132/133 [============================>.] - ETA: 0s - loss: 0.5325 - component_failure_loss: 0.0975 - time_to_failure_loss: 0.0069 - severity_loss: 0.4135 - component_failure_accuracy: 0.9676 - time_to_failure_mae: 0.0651 - severity_accuracy: 0.8288
# Epoch 29: val_loss did not improve from 0.55126
# 133/133 [==============================] - 7s 50ms/step - loss: 0.5333 - component_failure_loss: 0.0976 - time_to_failure_loss: 0.0069 - severity_loss: 0.4141 - component_failure_accuracy: 0.9675 - time_to_failure_mae: 0.0651 - severity_accuracy: 0.8288 - val_loss: 0.6134 - val_component_failure_loss: 0.1367 - val_time_to_failure_loss: 0.0057 - val_severity_loss: 0.4476 - val_component_failure_accuracy: 0.9559 - val_time_to_failure_mae: 0.0601 - val_severity_accuracy: 0.8051 - lr: 2.5000e-04
# Epoch 30/100
# 133/133 [==============================] - ETA: 0s - loss: 0.5337 - component_failure_loss: 0.1000 - time_to_failure_loss: 0.0068 - severity_loss: 0.4116 - component_failure_accuracy: 0.9674 - time_to_failure_mae: 0.0651 - severity_accuracy: 0.8319
# Epoch 30: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 30: val_loss did not improve from 0.55126
# 133/133 [==============================] - 7s 53ms/step - loss: 0.5337 - component_failure_loss: 0.1000 - time_to_failure_loss: 0.0068 - severity_loss: 0.4116 - component_failure_accuracy: 0.9674 - time_to_failure_mae: 0.0651 - severity_accuracy: 0.8319 - val_loss: 0.6102 - val_component_failure_loss: 0.1262 - val_time_to_failure_loss: 0.0055 - val_severity_loss: 0.4571 - val_component_failure_accuracy: 0.9559 - val_time_to_failure_mae: 0.0593 - val_severity_accuracy: 0.8037 - lr: 2.5000e-04
# Epoch 31/100
# 132/133 [============================>.] - ETA: 0s - loss: 0.5105 - component_failure_loss: 0.0958 - time_to_failure_loss: 0.0065 - severity_loss: 0.3935 - component_failure_accuracy: 0.9665 - time_to_failure_mae: 0.0631 - severity_accuracy: 0.8417
# Epoch 31: val_loss did not improve from 0.55126
# 133/133 [==============================] - 7s 50ms/step - loss: 0.5096 - component_failure_loss: 0.0954 - time_to_failure_loss: 0.0065 - severity_loss: 0.3931 - component_failure_accuracy: 0.9667 - time_to_failure_mae: 0.0630 - severity_accuracy: 0.8420 - val_loss: 0.6095 - val_component_failure_loss: 0.1285 - val_time_to_failure_loss: 0.0053 - val_severity_loss: 0.4537 - val_component_failure_accuracy: 0.9586 - val_time_to_failure_mae: 0.0574 - val_severity_accuracy: 0.8131 - lr: 1.2500e-04
# Epoch 32/100
# 132/133 [============================>.] - ETA: 0s - loss: 0.5036 - component_failure_loss: 0.0985 - time_to_failure_loss: 0.0064 - severity_loss: 0.3835 - component_failure_accuracy: 0.9666 - time_to_failure_mae: 0.0631 - severity_accuracy: 0.8443
# Epoch 32: val_loss did not improve from 0.55126
# 133/133 [==============================] - 7s 50ms/step - loss: 0.5030 - component_failure_loss: 0.0981 - time_to_failure_loss: 0.0064 - severity_loss: 0.3833 - component_failure_accuracy: 0.9668 - time_to_failure_mae: 0.0630 - severity_accuracy: 0.8446 - val_loss: 0.6062 - val_component_failure_loss: 0.1268 - val_time_to_failure_loss: 0.0054 - val_severity_loss: 0.4524 - val_component_failure_accuracy: 0.9573 - val_time_to_failure_mae: 0.0588 - val_severity_accuracy: 0.8051 - lr: 1.2500e-04
# Epoch 33/100
# 132/133 [============================>.] - ETA: 0s - loss: 0.4911 - component_failure_loss: 0.0843 - time_to_failure_loss: 0.0066 - severity_loss: 0.3880 - component_failure_accuracy: 0.9691 - time_to_failure_mae: 0.0638 - severity_accuracy: 0.8423
# Epoch 33: val_loss did not improve from 0.55126
# 133/133 [==============================] - 7s 50ms/step - loss: 0.4912 - component_failure_loss: 0.0844 - time_to_failure_loss: 0.0066 - severity_loss: 0.3880 - component_failure_accuracy: 0.9690 - time_to_failure_mae: 0.0638 - severity_accuracy: 0.8422 - val_loss: 0.6066 - val_component_failure_loss: 0.1221 - val_time_to_failure_loss: 0.0054 - val_severity_loss: 0.4584 - val_component_failure_accuracy: 0.9599 - val_time_to_failure_mae: 0.0585 - val_severity_accuracy: 0.8077 - lr: 1.2500e-04
# Epoch 34/100
# 132/133 [============================>.] - ETA: 0s - loss: 0.4903 - component_failure_loss: 0.0905 - time_to_failure_loss: 0.0065 - severity_loss: 0.3797 - component_failure_accuracy: 0.9688 - time_to_failure_mae: 0.0636 - severity_accuracy: 0.8449Restoring model weights from the end of the best epoch: 14.
#
# Epoch 34: val_loss did not improve from 0.55126
# 133/133 [==============================] - 7s 51ms/step - loss: 0.4912 - component_failure_loss: 0.0910 - time_to_failure_loss: 0.0065 - severity_loss: 0.3801 - component_failure_accuracy: 0.9687 - time_to_failure_mae: 0.0636 - severity_accuracy: 0.8445 - val_loss: 0.6200 - val_component_failure_loss: 0.1251 - val_time_to_failure_loss: 0.0054 - val_severity_loss: 0.4682 - val_component_failure_accuracy: 0.9579 - val_time_to_failure_mae: 0.0584 - val_severity_accuracy: 0.8104 - lr: 1.2500e-04
# Epoch 34: early stopping
#
# [SUCCESS] Training completed!
#
# [SUCCESS] Training completed!

# %%
print("\n[INFO] Evaluating model on test set...")

# Evaluate
test_results = model.evaluate(
    X_test,
    {
        'component_failure': y_comp_test,
        'time_to_failure': y_time_test,
        'severity': y_sev_test
    },
    verbose=0
)

print("\n" + "=" * 80)
print("TEST SET RESULTS")
print("=" * 80)
print(f"Total Loss: {test_results[0]:.4f}")
print(f"Component Failure Loss: {test_results[1]:.4f}")
print(f"Time to Failure Loss: {test_results[2]:.4f}")
print(f"Severity Loss: {test_results[3]:.4f}")
print(f"\n>>> Component Failure Accuracy: {test_results[4]*100:.2f}%")
print(f">>> Time to Failure MAE: {test_results[5]:.4f} (normalized)")
# Out:
# [INFO] Evaluating model on test set...
#
# ================================================================================
# TEST SET RESULTS
# ================================================================================
# Total Loss: 0.5513
# Component Failure Loss: 0.1056
# Time to Failure Loss: 0.0052
# Severity Loss: 0.4230
#
# >>> Component Failure Accuracy: 96.66%
# >>> Time to Failure MAE: 0.0560 (normalized)

# %%
print("\n[INFO] Performing detailed analysis...")

# Get predictions
predictions = model.predict(X_test)
pred_components = np.argmax(predictions[0], axis=1)
pred_severity = np.argmax(predictions[2], axis=1)

# Per-class accuracy
from sklearn.metrics import classification_report, confusion_matrix

components = ['engine', 'transmission', 'brakes', 'battery', 'cooling_system']
severities = ['low', 'medium', 'high', 'critical']

print("\n" + "=" * 80)
print("COMPONENT FAILURE - DETAILED METRICS")
print("=" * 80)
print(classification_report(y_comp_test, pred_components, target_names=components))

print("\n" + "=" * 80)
print("SEVERITY - DETAILED METRICS")
print("=" * 80)
print(classification_report(y_sev_test, pred_severity, target_names=severities))
# Out:
# [INFO] Performing detailed analysis...
# 47/47 [==============================] - 2s 11ms/step
#
# ================================================================================
# COMPONENT FAILURE - DETAILED METRICS
# ================================================================================
#                 precision    recall  f1-score   support
#
#         engine       0.98      0.95      0.97       300
#   transmission       0.98      0.96      0.97       312
#         brakes       0.93      0.97      0.95       295
#        battery       0.98      0.98      0.98       296
# cooling_system       0.97      0.98      0.97       295
#
#       accuracy                           0.97      1498
#      macro avg       0.97      0.97      0.97      1498
#   weighted avg       0.97      0.97      0.97      1498
#
#
# ================================================================================
# SEVERITY - DETAILED METRICS
# ================================================================================
#               precision    recall  f1-score   support
#
#          low       0.00      0.00      0.00         6
#       medium       0.64      0.61      0.62       147
#         high       0.79      0.78      0.78       635
#     critical       0.87      0.89      0.88       710
#
#     accuracy                           0.81      1498
#    macro avg       0.57      0.57      0.57      1498
# weighted avg       0.81      0.81      0.81      1498
# c:\Users\msaya\Miniconda3\envs\ey2\lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\msaya\Miniconda3\envs\ey2\lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\msaya\Miniconda3\envs\ey2\lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])

# %%
print("\n[INFO] Saving model and metadata...")

# Save final model
model.save('weights_and_metadata/vehicle_failure_lstm_optimized.keras')
print("[SUCCESS] Saved model to 'weights_and_metadata/vehicle_failure_lstm_optimized.keras'")

# Save model weights
model.save_weights('vehicle_failure_model.h5')
print("[SUCCESS] Saved weights to 'weights_and_metadata/vehicle_failure_model.h5'")



# Save metadata
metadata = {
    'num_samples': len(df),
    'num_sequences': len(X_sequences),
    'sequence_length': sequence_length,
    'num_features': len(feature_columns),
    'feature_columns': feature_columns,
    'components': components,
    'severities': severities,
    'train_samples': len(X_train),
    'test_samples': len(X_test),
    'model_params': int(model.count_params()),
    'final_metrics': {
        'test_loss': float(test_results[0]),
        'component_accuracy': float(test_results[4]),
        'time_mae': float(test_results[5]),
        'severity_accuracy': float(test_results[6])
    }
}

with open('weights_and_metadata/model_metadata_optimized.json', 'w') as f:
    json.dump(metadata, f, indent=2)
print("[SUCCESS] Saved metadata to 'weights_and_metadata/model_metadata_optimized.json'")
# Out:
# [INFO] Saving model and metadata...
# [SUCCESS] Saved model to 'weights_and_metadata/vehicle_failure_lstm_optimized.keras'
# [SUCCESS] Saved weights to 'weights_and_metadata/vehicle_failure_model.h5'
# [SUCCESS] Saved metadata to 'weights_and_metadata/model_metadata_optimized.json'
