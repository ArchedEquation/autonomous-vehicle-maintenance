# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, models
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
import pickle
import json

# %%
def generate_synthetic_data(num_samples=10000):
    """Generate synthetic vehicle telematics with stronger feature correlations"""
    
    print(f"\n[INFO] Generating {num_samples} synthetic samples with enhanced correlations...")
    
    components = ['engine', 'transmission', 'brakes', 'battery', 'cooling_system']
    severities = ['low', 'medium', 'high', 'critical']
    
    data = []
    
    for i in range(num_samples):
        # Select component that will fail
        failing_component = np.random.choice(components)
        component_index = components.index(failing_component)
        
        # Generate time to failure with more variation
        time_to_failure = np.random.beta(2, 5) * 365  # More samples near failure
        
        # Stronger health factor correlation
        health_factor = max(0, 1 - (time_to_failure / 365))
        health_squared = health_factor ** 2  # Non-linear degradation
        
        # Base noise
        noise = lambda scale=1.0: np.random.normal(0, 0.05 * scale)
        
        # Component-specific feature generation with stronger signals
        if failing_component == 'engine':
            engine_degradation = health_squared * 50 + noise(10)
            rpm_variance = health_squared * 1500 + noise(200)
            oil_drop = health_squared * 30 + noise(5)
            vibration_increase = health_squared * 12 + noise(2)
            emission_increase = health_squared * 120 + noise(20)
        else:
            engine_degradation = noise(5)
            rpm_variance = noise(100)
            oil_drop = noise(2)
            vibration_increase = noise(1)
            emission_increase = noise(10)
        
        if failing_component == 'transmission':
            trans_vibration = health_squared * 15 + noise(2)
            acceleration_issue = health_squared * 8 + noise(1)
        else:
            trans_vibration = noise(1)
            acceleration_issue = noise(0.5)
        
        if failing_component == 'brakes':
            brake_degradation = health_squared * 10 + noise(1)
            noise_increase = health_squared * 30 + noise(5)
        else:
            brake_degradation = noise(0.5)
            noise_increase = noise(3)
        
        if failing_component == 'battery':
            voltage_drop = health_squared * 3 + noise(0.2)
        else:
            voltage_drop = noise(0.1)
        
        if failing_component == 'cooling_system':
            coolant_drop = health_squared * 50 + noise(5)
            temp_increase = health_squared * 40 + noise(5)
        else:
            coolant_drop = noise(2)
            temp_increase = noise(3)
        
        # Generate features with stronger correlations
        sample = {
            # Telematics data
            'engine_temp': 75 + np.random.uniform(-5, 15) + engine_degradation + temp_increase,
            'rpm': 2000 + np.random.uniform(-500, 2000) + rpm_variance,
            'fuel_consumption': 7 + np.random.uniform(-1, 3) + (engine_degradation * 0.1),
            'battery_voltage': 13.5 + np.random.uniform(-0.5, 0.5) - voltage_drop,
            'oil_pressure': 45 + np.random.uniform(-10, 15) - oil_drop,
            'coolant_level': 90 + np.random.uniform(-5, 10) - coolant_drop,
            
            # Usage patterns (correlated with failure)
            'mileage': np.random.uniform(50000, 250000) + (health_factor * 100000),
            'avg_speed': 50 + np.random.uniform(-20, 30),
            'acceleration': np.random.uniform(2, 8) + acceleration_issue,
            'braking': np.random.uniform(2, 8) + brake_degradation,
            'trip_duration': np.random.uniform(20, 180),
            
            # Environmental
            'ambient_temp': np.random.uniform(-5, 40),
            'humidity': np.random.uniform(20, 90),
            'road_condition': np.random.beta(2, 2),  # More centered distribution
            
            # Historical (correlated with failure)
            'vehicle_age': np.random.uniform(1, 15) + (health_factor * 8),
            'last_maintenance_days': np.random.uniform(30, 300) + (health_factor * 200),
            'previous_failures': np.random.poisson(health_factor * 3),
            
            # Sensor readings
            'vibration': np.random.uniform(1, 5) + vibration_increase + trans_vibration,
            'noise_level': 50 + np.random.uniform(-10, 20) + noise_increase,
            'emissions': 80 + np.random.uniform(-20, 40) + emission_increase,
            
            # Outputs - with clearer severity mapping
            'component_failure': component_index,
            'time_to_failure': time_to_failure,
            'severity': int(health_factor * 3.99)  # 0-3 mapping to ensure coverage
        }
        
        data.append(sample)
    
    df = pd.DataFrame(data)
    
    # Add interaction features (feature engineering)
    df['temp_rpm_interaction'] = df['engine_temp'] * df['rpm'] / 10000
    df['age_mileage_ratio'] = df['vehicle_age'] / (df['mileage'] / 10000 + 1)
    df['maintenance_mileage'] = df['last_maintenance_days'] * df['mileage'] / 100000
    df['vibration_noise'] = df['vibration'] * df['noise_level'] / 100
    
    print(f"[SUCCESS] Generated {len(df)} samples with {len(df.columns)} features")
    
    return df

# Generate more data
df = generate_synthetic_data(10000)

# Save raw data
df.to_csv('data/vehicle_failure_data.csv', index=False)
print(f"[SUCCESS] Saved raw data to 'data/vehicle_failure_data.csv'")
# Out:
# [INFO] Generating 10000 synthetic samples with enhanced correlations...
# [SUCCESS] Generated 10000 samples with 27 features
# [SUCCESS] Saved raw data to 'data/vehicle_failure_data.csv'

# %%
print("\n[INFO] Preprocessing data...")

# Separate features and targets
feature_columns = [
    'engine_temp', 'rpm', 'fuel_consumption', 'battery_voltage', 'oil_pressure', 'coolant_level',
    'mileage', 'avg_speed', 'acceleration', 'braking', 'trip_duration',
    'ambient_temp', 'humidity', 'road_condition',
    'vehicle_age', 'last_maintenance_days', 'previous_failures',
    'vibration', 'noise_level', 'emissions',
    'temp_rpm_interaction', 'age_mileage_ratio', 'maintenance_mileage', 'vibration_noise'
]

X = df[feature_columns].values
y_component = df['component_failure'].values
y_time = df['time_to_failure'].values / 365.0  # Normalize to 0-1
y_severity = df['severity'].values

# Standardize features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Save scaler
with open('scaler.pkl', 'wb') as f:
    pickle.dump(scaler, f)
print("[SUCCESS] Saved scaler to 'scaler.pkl'")
# Out:
# [INFO] Preprocessing data...
# [SUCCESS] Saved scaler to 'scaler.pkl'

# %%
def create_sequences(X, y_comp, y_time, y_sev, seq_length=15):
    """Create sequences for LSTM input"""
    
    print(f"[INFO] Creating sequences with length {seq_length}...")
    
    X_seq, y_comp_seq, y_time_seq, y_sev_seq = [], [], [], []
    
    for i in range(len(X) - seq_length):
        X_seq.append(X[i:i+seq_length])
        y_comp_seq.append(y_comp[i+seq_length-1])
        y_time_seq.append(y_time[i+seq_length-1])
        y_sev_seq.append(y_sev[i+seq_length-1])
    
    return (
        np.array(X_seq),
        np.array(y_comp_seq),
        np.array(y_time_seq),
        np.array(y_sev_seq)
    )

sequence_length = 15  # Longer sequences for better pattern recognition
X_sequences, y_comp_seq, y_time_seq, y_sev_seq = create_sequences(
    X_scaled, y_component, y_time, y_severity, sequence_length
)

print(f"[SUCCESS] Created {len(X_sequences)} sequences")
print(f"[INFO] Sequence shape: {X_sequences.shape}")
# Out:
# [INFO] Creating sequences with length 15...
# [SUCCESS] Created 9985 sequences
# [INFO] Sequence shape: (9985, 15, 24)

# %%
X_train, X_test, y_comp_train, y_comp_test, y_time_train, y_time_test, y_sev_train, y_sev_test = train_test_split(
    X_sequences, y_comp_seq, y_time_seq, y_sev_seq,
    test_size=0.15,  # Slightly smaller test set for more training data
    random_state=42,
    stratify=y_comp_seq  # Stratify by component
)

print(f"\n[INFO] Train set: {len(X_train)} samples")
print(f"[INFO] Test set: {len(X_test)} samples")
# Out:
# [INFO] Train set: 8487 samples
# [INFO] Test set: 1498 samples

# %%
print("\n[INFO] Building optimized LSTM model architecture...")

def build_optimized_lstm(input_shape, num_components=5, num_severities=4):
    """Build deeper, more powerful LSTM model"""
    
    # Input layer
    inputs = layers.Input(shape=input_shape, name='input')
    
    # Bidirectional LSTM layers for better context
    x = layers.Bidirectional(layers.LSTM(256, return_sequences=True))(inputs)
    x = layers.BatchNormalization()(x)
    x = layers.Dropout(0.4)(x)
    
    x = layers.Bidirectional(layers.LSTM(128, return_sequences=True))(x)
    x = layers.BatchNormalization()(x)
    x = layers.Dropout(0.4)(x)
    
    x = layers.LSTM(64, return_sequences=False)(x)
    x = layers.BatchNormalization()(x)
    x = layers.Dropout(0.3)(x)
    
    # Shared dense layers
    x = layers.Dense(128, activation='relu')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Dropout(0.3)(x)
    
    x = layers.Dense(64, activation='relu')(x)
    x = layers.Dropout(0.2)(x)
    
    # Task-specific heads with additional layers
    # Component failure head
    comp_x = layers.Dense(32, activation='relu', name='comp_dense')(x)
    component_output = layers.Dense(num_components, activation='softmax', name='component_failure')(comp_x)
    
    # Time to failure head
    time_x = layers.Dense(32, activation='relu', name='time_dense')(x)
    time_output = layers.Dense(1, activation='sigmoid', name='time_to_failure')(time_x)
    
    # Severity head
    sev_x = layers.Dense(32, activation='relu', name='sev_dense')(x)
    severity_output = layers.Dense(num_severities, activation='softmax', name='severity')(sev_x)
    
    # Create model
    model = models.Model(
        inputs=inputs,
        outputs=[component_output, time_output, severity_output]
    )
    
    return model
# Out:
# [INFO] Building optimized LSTM model architecture...

# %%
input_shape = (sequence_length, len(feature_columns))
model = build_optimized_lstm(input_shape)

# %%
model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=0.0005),  # Lower learning rate
    loss={
        'component_failure': 'sparse_categorical_crossentropy',
        'time_to_failure': 'mse',
        'severity': 'sparse_categorical_crossentropy'
    },
    loss_weights={
        'component_failure': 1.2,  # Increased weight
        'time_to_failure': 0.3,    # Decreased weight (regression is easier)
        'severity': 1.0
    },
    metrics={
        'component_failure': ['accuracy'],
        'time_to_failure': ['mae'],
        'severity': ['accuracy']
    }
)

print("[SUCCESS] Model architecture built")
print(f"[INFO] Total parameters: {model.count_params():,}")
model.summary()
# Out:
# [SUCCESS] Model architecture built
# [INFO] Total parameters: 1,341,034
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input (InputLayer)  │ (None, 15, 24)    │          0 │ -                 │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bidirectional       │ (None, 15, 512)   │    575,488 │ input[0][0]       │
# │ (Bidirectional)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 15, 512)   │      2,048 │ bidirectional[0]… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_3 (Dropout) │ (None, 15, 512)   │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bidirectional_1     │ (None, 15, 256)   │    656,384 │ dropout_3[0][0]   │
# │ (Bidirectional)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 15, 256)   │      1,024 │ bidirectional_1[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_4 (Dropout) │ (None, 15, 256)   │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm_4 (LSTM)       │ (None, 64)        │     82,176 │ dropout_4[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64)        │        256 │ lstm_4[0][0]      │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_5 (Dropout) │ (None, 64)        │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 128)       │      8,320 │ dropout_5[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128)       │        512 │ dense_1[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_6 (Dropout) │ (None, 128)       │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 64)        │      8,256 │ dropout_6[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_7 (Dropout) │ (None, 64)        │          0 │ dense_2[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ comp_dense (Dense)  │ (None, 32)        │      2,080 │ dropout_7[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ time_dense (Dense)  │ (None, 32)        │      2,080 │ dropout_7[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sev_dense (Dense)   │ (None, 32)        │      2,080 │ dropout_7[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ component_failure   │ (None, 5)         │        165 │ comp_dense[0][0]  │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ time_to_failure     │ (None, 1)         │         33 │ time_dense[0][0]  │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ severity (Dense)    │ (None, 4)         │        132 │ sev_dense[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 1,341,034 (5.12 MB)
#  Trainable params: 1,339,114 (5.11 MB)
#  Non-trainable params: 1,920 (7.50 KB)

# %%
print("\n[INFO] Starting model training...")

callbacks = [
    EarlyStopping(
        monitor='val_loss',
        patience=20,  # More patience
        restore_best_weights=True,
        verbose=1
    ),
    ReduceLROnPlateau(
        monitor='val_loss',
        factor=0.5,
        patience=8,
        min_lr=1e-7,
        verbose=1
    ),
    ModelCheckpoint(
        'best_model.keras',
        monitor='val_loss',
        save_best_only=True,
        verbose=1
    )
]

# Train model with more epochs
history = model.fit(
    X_train,
    {
        'component_failure': y_comp_train,
        'time_to_failure': y_time_train,
        'severity': y_sev_train
    },
    validation_data=(
        X_test,
        {
            'component_failure': y_comp_test,
            'time_to_failure': y_time_test,
            'severity': y_sev_test
        }
    ),
    epochs=100,  # More epochs
    batch_size=64,  # Larger batch size
    callbacks=callbacks,
    verbose=1
)

print("\n[SUCCESS] Training completed!")

print("\n[SUCCESS] Training completed!")
# Out:
# [INFO] Starting model training...
# Epoch 1/100
# 132/133 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - component_failure_accuracy: 0.2744 - component_failure_loss: 1.7632 - loss: 3.4599 - severity_accuracy: 0.4103 - severity_loss: 1.3159 - time_to_failure_loss: 0.0940 - time_to_failure_mae: 0.2395
# Epoch 1: val_loss improved from None to 2.96591, saving model to best_model.keras
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 15s 72ms/step - component_failure_accuracy: 0.3310 - component_failure_loss: 1.5759 - loss: 3.0800 - severity_accuracy: 0.4415 - severity_loss: 1.1687 - time_to_failure_loss: 0.0606 - time_to_failure_mae: 0.1916 - val_component_failure_accuracy: 0.4326 - val_component_failure_loss: 1.4890 - val_loss: 2.9659 - val_severity_accuracy: 0.4773 - val_severity_loss: 1.1699 - val_time_to_failure_loss: 0.0390 - val_time_to_failure_mae: 0.1694 - learning_rate: 5.0000e-04
# Epoch 2/100
# 132/133 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - component_failure_accuracy: 0.5210 - component_failure_loss: 1.1995 - loss: 2.4534 - severity_accuracy: 0.4857 - severity_loss: 1.0034 - time_to_failure_loss: 0.0353 - time_to_failure_mae: 0.1482
# Epoch 2: val_loss improved from 2.96591 to 1.93136, saving model to best_model.keras
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 9s 65ms/step - component_failure_accuracy: 0.5837 - component_failure_loss: 1.0658 - loss: 2.2558 - severity_accuracy: 0.5038 - severity_loss: 0.9657 - time_to_failure_loss: 0.0314 - time_to_failure_mae: 0.1401 - val_component_failure_accuracy: 0.6929 - val_component_failure_loss: 0.8396 - val_loss: 1.9314 - val_severity_accuracy: 0.5641 - val_severity_loss: 0.9273 - val_time_to_failure_loss: 0.0246 - val_time_to_failure_mae: 0.1297 - learning_rate: 5.0000e-04
# Epoch 3/100
# 132/133 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - component_failure_accuracy: 0.7679 - component_failure_loss: 0.6385 - loss: 1.6440 - severity_accuracy: 0.5667 - severity_loss: 0.8706 - time_to_failure_loss: 0.0238 - time_to_failure_mae: 0.1220
# Epoch 3: val_loss improved from 1.93136 to 1.10603, saving model to best_model.keras
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 9s 65ms/step - component_failure_accuracy: 0.8107 - component_failure_loss: 0.5377 - loss: 1.4955 - severity_accuracy: 0.5884 - severity_loss: 0.8430 - time_to_failure_loss: 0.0217 - time_to_failure_mae: 0.1161 - val_component_failure_accuracy: 0.8872 - val_component_failure_loss: 0.3066 - val_loss: 1.1060 - val_severity_accuracy: 0.6455 - val_severity_loss: 0.7454 - val_time_to_failure_loss: 0.0140 - val_time_to_failure_mae: 0.0935 - learning_rate: 5.0000e-04
# Epoch 4/100
# 132/133 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - component_failure_accuracy: 0.8951 - component_failure_loss: 0.3131 - loss: 1.1476 - severity_accuracy: 0.6346 - severity_loss: 0.7666 - time_to_failure_loss: 0.0174 - time_to_failure_mae: 0.1041
# Epoch 4: val_loss improved from 1.10603 to 0.80381, saving model to best_model.keras
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 9s 65ms/step - component_failure_accuracy: 0.8961 - component_failure_loss: 0.3035 - loss: 1.1205 - severity_accuracy: 0.6407 - severity_loss: 0.7508 - time_to_failure_loss: 0.0164 - time_to_failure_mae: 0.1010 - val_component_failure_accuracy: 0.9546 - val_component_failure_loss: 0.1595 - val_loss: 0.8038 - val_severity_accuracy: 0.7350 - val_severity_loss: 0.6198 - val_time_to_failure_loss: 0.0076 - val_time_to_failure_mae: 0.0673 - learning_rate: 5.0000e-04
# Epoch 5/100
# 132/133 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - component_failure_accuracy: 0.9072 - component_failure_loss: 0.2599 - loss: 1.0180 - severity_accuracy: 0.6663 - severity_loss: 0.7018 - time_to_failure_loss: 0.0145 - time_to_failure_mae: 0.0951
# Epoch 5: val_loss improved from 0.80381 to 0.73954, saving model to best_model.keras
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 9s 66ms/step - component_failure_accuracy: 0.9115 - component_failure_loss: 0.2538 - loss: 0.9954 - severity_accuracy: 0.6759 - severity_loss: 0.6872 - time_to_failure_loss: 0.0139 - time_to_failure_mae: 0.0933 - val_component_failure_accuracy: 0.9479 - val_component_failure_loss: 0.1524 - val_loss: 0.7395 - val_severity_accuracy: 0.7603 - val_severity_loss: 0.5635 - val_time_to_failure_loss: 0.0065 - val_time_to_failure_mae: 0.0631 - learning_rate: 5.0000e-04
# Epoch 6/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - component_failure_accuracy: 0.9213 - component_failure_loss: 0.2222 - loss: 0.9373 - severity_accuracy: 0.6927 - severity_loss: 0.6666 - time_to_failure_loss: 0.0135 - time_to_failure_mae: 0.0918
# Epoch 6: val_loss improved from 0.73954 to 0.70401, saving model to best_model.keras
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 9s 67ms/step - component_failure_accuracy: 0.9248 - component_failure_loss: 0.2133 - loss: 0.9193 - severity_accuracy: 0.6992 - severity_loss: 0.6592 - time_to_failure_loss: 0.0131 - time_to_failure_mae: 0.0902 - val_component_failure_accuracy: 0.9553 - val_component_failure_loss: 0.1311 - val_loss: 0.7040 - val_severity_accuracy: 0.7644 - val_severity_loss: 0.5506 - val_time_to_failure_loss: 0.0062 - val_time_to_failure_mae: 0.0612 - learning_rate: 5.0000e-04
# Epoch 7/100
# 132/133 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - component_failure_accuracy: 0.9261 - component_failure_loss: 0.2060 - loss: 0.8750 - severity_accuracy: 0.7138 - severity_loss: 0.6242 - time_to_failure_loss: 0.0121 - time_to_failure_mae: 0.0866
# Epoch 7: val_loss improved from 0.70401 to 0.65663, saving model to best_model.keras
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 9s 68ms/step - component_failure_accuracy: 0.9320 - component_failure_loss: 0.2019 - loss: 0.8660 - severity_accuracy: 0.7166 - severity_loss: 0.6198 - time_to_failure_loss: 0.0118 - time_to_failure_mae: 0.0857 - val_component_failure_accuracy: 0.9586 - val_component_failure_loss: 0.1266 - val_loss: 0.6566 - val_severity_accuracy: 0.7897 - val_severity_loss: 0.5097 - val_time_to_failure_loss: 0.0060 - val_time_to_failure_mae: 0.0599 - learning_rate: 5.0000e-04
# Epoch 8/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - component_failure_accuracy: 0.9344 - component_failure_loss: 0.1873 - loss: 0.8093 - severity_accuracy: 0.7439 - severity_loss: 0.5813 - time_to_failure_loss: 0.0109 - time_to_failure_mae: 0.0825
# Epoch 8: val_loss improved from 0.65663 to 0.65134, saving model to best_model.keras
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 9s 69ms/step - component_failure_accuracy: 0.9332 - component_failure_loss: 0.1875 - loss: 0.8181 - severity_accuracy: 0.7351 - severity_loss: 0.5894 - time_to_failure_loss: 0.0107 - time_to_failure_mae: 0.0819 - val_component_failure_accuracy: 0.9553 - val_component_failure_loss: 0.1270 - val_loss: 0.6513 - val_severity_accuracy: 0.7817 - val_severity_loss: 0.5055 - val_time_to_failure_loss: 0.0058 - val_time_to_failure_mae: 0.0582 - learning_rate: 5.0000e-04
# Epoch 9/100
# 132/133 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - component_failure_accuracy: 0.9379 - component_failure_loss: 0.1862 - loss: 0.8140 - severity_accuracy: 0.7285 - severity_loss: 0.5874 - time_to_failure_loss: 0.0108 - time_to_failure_mae: 0.0821
# Epoch 9: val_loss improved from 0.65134 to 0.63951, saving model to best_model.keras
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 9s 71ms/step - component_failure_accuracy: 0.9399 - component_failure_loss: 0.1781 - loss: 0.7947 - severity_accuracy: 0.7388 - severity_loss: 0.5776 - time_to_failure_loss: 0.0106 - time_to_failure_mae: 0.0815 - val_component_failure_accuracy: 0.9573 - val_component_failure_loss: 0.1231 - val_loss: 0.6395 - val_severity_accuracy: 0.7750 - val_severity_loss: 0.4977 - val_time_to_failure_loss: 0.0057 - val_time_to_failure_mae: 0.0576 - learning_rate: 5.0000e-04
# Epoch 10/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - component_failure_accuracy: 0.9451 - component_failure_loss: 0.1661 - loss: 0.7512 - severity_accuracy: 0.7594 - severity_loss: 0.5487 - time_to_failure_loss: 0.0101 - time_to_failure_mae: 0.0790
# Epoch 10: val_loss improved from 0.63951 to 0.62413, saving model to best_model.keras
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 9s 68ms/step - component_failure_accuracy: 0.9427 - component_failure_loss: 0.1695 - loss: 0.7637 - severity_accuracy: 0.7557 - severity_loss: 0.5577 - time_to_failure_loss: 0.0098 - time_to_failure_mae: 0.0780 - val_component_failure_accuracy: 0.9613 - val_component_failure_loss: 0.1184 - val_loss: 0.6241 - val_severity_accuracy: 0.7837 - val_severity_loss: 0.4880 - val_time_to_failure_loss: 0.0056 - val_time_to_failure_mae: 0.0584 - learning_rate: 5.0000e-04
# Epoch 11/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - component_failure_accuracy: 0.9460 - component_failure_loss: 0.1532 - loss: 0.7419 - severity_accuracy: 0.7534 - severity_loss: 0.5551 - time_to_failure_loss: 0.0095 - time_to_failure_mae: 0.0769
# Epoch 11: val_loss did not improve from 0.62413
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 9s 67ms/step - component_failure_accuracy: 0.9447 - component_failure_loss: 0.1604 - loss: 0.7505 - severity_accuracy: 0.7550 - severity_loss: 0.5558 - time_to_failure_loss: 0.0095 - time_to_failure_mae: 0.0770 - val_component_failure_accuracy: 0.9586 - val_component_failure_loss: 0.1206 - val_loss: 0.6248 - val_severity_accuracy: 0.7971 - val_severity_loss: 0.4865 - val_time_to_failure_loss: 0.0058 - val_time_to_failure_mae: 0.0593 - learning_rate: 5.0000e-04
# Epoch 12/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - component_failure_accuracy: 0.9535 - component_failure_loss: 0.1485 - loss: 0.7358 - severity_accuracy: 0.7564 - severity_loss: 0.5548 - time_to_failure_loss: 0.0094 - time_to_failure_mae: 0.0761
# Epoch 12: val_loss improved from 0.62413 to 0.61427, saving model to best_model.keras
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 9s 69ms/step - component_failure_accuracy: 0.9500 - component_failure_loss: 0.1523 - loss: 0.7385 - severity_accuracy: 0.7536 - severity_loss: 0.5527 - time_to_failure_loss: 0.0095 - time_to_failure_mae: 0.0766 - val_component_failure_accuracy: 0.9613 - val_component_failure_loss: 0.1166 - val_loss: 0.6143 - val_severity_accuracy: 0.7917 - val_severity_loss: 0.4813 - val_time_to_failure_loss: 0.0058 - val_time_to_failure_mae: 0.0589 - learning_rate: 5.0000e-04
# Epoch 13/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - component_failure_accuracy: 0.9504 - component_failure_loss: 0.1503 - loss: 0.7204 - severity_accuracy: 0.7662 - severity_loss: 0.5374 - time_to_failure_loss: 0.0088 - time_to_failure_mae: 0.0737
# Epoch 13: val_loss improved from 0.61427 to 0.59275, saving model to best_model.keras
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 9s 69ms/step - component_failure_accuracy: 0.9511 - component_failure_loss: 0.1495 - loss: 0.7160 - severity_accuracy: 0.7702 - severity_loss: 0.5347 - time_to_failure_loss: 0.0091 - time_to_failure_mae: 0.0745 - val_component_failure_accuracy: 0.9586 - val_component_failure_loss: 0.1158 - val_loss: 0.5928 - val_severity_accuracy: 0.8011 - val_severity_loss: 0.4613 - val_time_to_failure_loss: 0.0056 - val_time_to_failure_mae: 0.0571 - learning_rate: 5.0000e-04
# Epoch 14/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - component_failure_accuracy: 0.9537 - component_failure_loss: 0.1369 - loss: 0.7006 - severity_accuracy: 0.7631 - severity_loss: 0.5337 - time_to_failure_loss: 0.0090 - time_to_failure_mae: 0.0748
# Epoch 14: val_loss did not improve from 0.59275
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 9s 69ms/step - component_failure_accuracy: 0.9530 - component_failure_loss: 0.1396 - loss: 0.7012 - severity_accuracy: 0.7672 - severity_loss: 0.5314 - time_to_failure_loss: 0.0089 - time_to_failure_mae: 0.0744 - val_component_failure_accuracy: 0.9579 - val_component_failure_loss: 0.1226 - val_loss: 0.6122 - val_severity_accuracy: 0.7977 - val_severity_loss: 0.4728 - val_time_to_failure_loss: 0.0057 - val_time_to_failure_mae: 0.0579 - learning_rate: 5.0000e-04
# Epoch 15/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - component_failure_accuracy: 0.9532 - component_failure_loss: 0.1365 - loss: 0.6834 - severity_accuracy: 0.7752 - severity_loss: 0.5169 - time_to_failure_loss: 0.0089 - time_to_failure_mae: 0.0744
# Epoch 15: val_loss improved from 0.59275 to 0.58256, saving model to best_model.keras
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 9s 67ms/step - component_failure_accuracy: 0.9536 - component_failure_loss: 0.1367 - loss: 0.6847 - severity_accuracy: 0.7774 - severity_loss: 0.5175 - time_to_failure_loss: 0.0088 - time_to_failure_mae: 0.0739 - val_component_failure_accuracy: 0.9633 - val_component_failure_loss: 0.1055 - val_loss: 0.5826 - val_severity_accuracy: 0.7944 - val_severity_loss: 0.4638 - val_time_to_failure_loss: 0.0055 - val_time_to_failure_mae: 0.0573 - learning_rate: 5.0000e-04
# Epoch 16/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - component_failure_accuracy: 0.9506 - component_failure_loss: 0.1410 - loss: 0.6914 - severity_accuracy: 0.7762 - severity_loss: 0.5197 - time_to_failure_loss: 0.0084 - time_to_failure_mae: 0.0729
# Epoch 16: val_loss did not improve from 0.58256
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 9s 68ms/step - component_failure_accuracy: 0.9542 - component_failure_loss: 0.1349 - loss: 0.6836 - severity_accuracy: 0.7781 - severity_loss: 0.5197 - time_to_failure_loss: 0.0085 - time_to_failure_mae: 0.0729 - val_component_failure_accuracy: 0.9599 - val_component_failure_loss: 0.1141 - val_loss: 0.6038 - val_severity_accuracy: 0.7904 - val_severity_loss: 0.4730 - val_time_to_failure_loss: 0.0053 - val_time_to_failure_mae: 0.0561 - learning_rate: 5.0000e-04
# Epoch 17/100
# 132/133 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - component_failure_accuracy: 0.9540 - component_failure_loss: 0.1333 - loss: 0.6559 - severity_accuracy: 0.7890 - severity_loss: 0.4936 - time_to_failure_loss: 0.0080 - time_to_failure_mae: 0.0709
# Epoch 17: val_loss did not improve from 0.58256
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 9s 67ms/step - component_failure_accuracy: 0.9568 - component_failure_loss: 0.1311 - loss: 0.6607 - severity_accuracy: 0.7850 - severity_loss: 0.5009 - time_to_failure_loss: 0.0080 - time_to_failure_mae: 0.0708 - val_component_failure_accuracy: 0.9579 - val_component_failure_loss: 0.1173 - val_loss: 0.5999 - val_severity_accuracy: 0.7977 - val_severity_loss: 0.4666 - val_time_to_failure_loss: 0.0060 - val_time_to_failure_mae: 0.0590 - learning_rate: 5.0000e-04
# Epoch 18/100
# 132/133 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - component_failure_accuracy: 0.9536 - component_failure_loss: 0.1373 - loss: 0.6476 - severity_accuracy: 0.7939 - severity_loss: 0.4804 - time_to_failure_loss: 0.0081 - time_to_failure_mae: 0.0703
# Epoch 18: val_loss did not improve from 0.58256
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 9s 67ms/step - component_failure_accuracy: 0.9544 - component_failure_loss: 0.1361 - loss: 0.6529 - severity_accuracy: 0.7872 - severity_loss: 0.4878 - time_to_failure_loss: 0.0080 - time_to_failure_mae: 0.0701 - val_component_failure_accuracy: 0.9586 - val_component_failure_loss: 0.1155 - val_loss: 0.5957 - val_severity_accuracy: 0.8011 - val_severity_loss: 0.4670 - val_time_to_failure_loss: 0.0055 - val_time_to_failure_mae: 0.0576 - learning_rate: 5.0000e-04
# Epoch 19/100
# 132/133 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - component_failure_accuracy: 0.9598 - component_failure_loss: 0.1185 - loss: 0.6241 - severity_accuracy: 0.7967 - severity_loss: 0.4795 - time_to_failure_loss: 0.0083 - time_to_failure_mae: 0.0721
# Epoch 19: val_loss did not improve from 0.58256
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 9s 68ms/step - component_failure_accuracy: 0.9588 - component_failure_loss: 0.1230 - loss: 0.6371 - severity_accuracy: 0.7906 - severity_loss: 0.4866 - time_to_failure_loss: 0.0080 - time_to_failure_mae: 0.0708 - val_component_failure_accuracy: 0.9593 - val_component_failure_loss: 0.1218 - val_loss: 0.6066 - val_severity_accuracy: 0.7977 - val_severity_loss: 0.4698 - val_time_to_failure_loss: 0.0056 - val_time_to_failure_mae: 0.0574 - learning_rate: 5.0000e-04
# Epoch 20/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - component_failure_accuracy: 0.9575 - component_failure_loss: 0.1140 - loss: 0.6237 - severity_accuracy: 0.7940 - severity_loss: 0.4846 - time_to_failure_loss: 0.0079 - time_to_failure_mae: 0.0697
# Epoch 20: val_loss did not improve from 0.58256
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 9s 67ms/step - component_failure_accuracy: 0.9582 - component_failure_loss: 0.1176 - loss: 0.6326 - severity_accuracy: 0.7929 - severity_loss: 0.4891 - time_to_failure_loss: 0.0078 - time_to_failure_mae: 0.0697 - val_component_failure_accuracy: 0.9573 - val_component_failure_loss: 0.1209 - val_loss: 0.6072 - val_severity_accuracy: 0.7884 - val_severity_loss: 0.4728 - val_time_to_failure_loss: 0.0057 - val_time_to_failure_mae: 0.0578 - learning_rate: 5.0000e-04
# Epoch 21/100
# 132/133 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - component_failure_accuracy: 0.9561 - component_failure_loss: 0.1276 - loss: 0.6243 - severity_accuracy: 0.8007 - severity_loss: 0.4689 - time_to_failure_loss: 0.0077 - time_to_failure_mae: 0.0686
# Epoch 21: val_loss did not improve from 0.58256
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 9s 67ms/step - component_failure_accuracy: 0.9573 - component_failure_loss: 0.1269 - loss: 0.6340 - severity_accuracy: 0.7958 - severity_loss: 0.4792 - time_to_failure_loss: 0.0077 - time_to_failure_mae: 0.0689 - val_component_failure_accuracy: 0.9599 - val_component_failure_loss: 0.1129 - val_loss: 0.5994 - val_severity_accuracy: 0.7911 - val_severity_loss: 0.4734 - val_time_to_failure_loss: 0.0056 - val_time_to_failure_mae: 0.0578 - learning_rate: 5.0000e-04
# Epoch 22/100
# 132/133 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - component_failure_accuracy: 0.9566 - component_failure_loss: 0.1261 - loss: 0.6390 - severity_accuracy: 0.7995 - severity_loss: 0.4854 - time_to_failure_loss: 0.0079 - time_to_failure_mae: 0.0702
# Epoch 22: val_loss did not improve from 0.58256
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 9s 67ms/step - component_failure_accuracy: 0.9575 - component_failure_loss: 0.1266 - loss: 0.6358 - severity_accuracy: 0.8000 - severity_loss: 0.4815 - time_to_failure_loss: 0.0078 - time_to_failure_mae: 0.0696 - val_component_failure_accuracy: 0.9593 - val_component_failure_loss: 0.1192 - val_loss: 0.6057 - val_severity_accuracy: 0.7864 - val_severity_loss: 0.4728 - val_time_to_failure_loss: 0.0060 - val_time_to_failure_mae: 0.0593 - learning_rate: 5.0000e-04
# Epoch 23/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - component_failure_accuracy: 0.9599 - component_failure_loss: 0.1264 - loss: 0.6050 - severity_accuracy: 0.8129 - severity_loss: 0.4512 - time_to_failure_loss: 0.0075 - time_to_failure_mae: 0.0682
# Epoch 23: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 23: val_loss did not improve from 0.58256
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 10s 71ms/step - component_failure_accuracy: 0.9604 - component_failure_loss: 0.1198 - loss: 0.6115 - severity_accuracy: 0.8041 - severity_loss: 0.4653 - time_to_failure_loss: 0.0076 - time_to_failure_mae: 0.0689 - val_component_failure_accuracy: 0.9586 - val_component_failure_loss: 0.1206 - val_loss: 0.6195 - val_severity_accuracy: 0.7837 - val_severity_loss: 0.4825 - val_time_to_failure_loss: 0.0057 - val_time_to_failure_mae: 0.0580 - learning_rate: 5.0000e-04
# Epoch 24/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - component_failure_accuracy: 0.9627 - component_failure_loss: 0.1145 - loss: 0.6033 - severity_accuracy: 0.8060 - severity_loss: 0.4638 - time_to_failure_loss: 0.0071 - time_to_failure_mae: 0.0663
# Epoch 24: val_loss did not improve from 0.58256
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 9s 68ms/step - component_failure_accuracy: 0.9623 - component_failure_loss: 0.1119 - loss: 0.5966 - severity_accuracy: 0.8044 - severity_loss: 0.4603 - time_to_failure_loss: 0.0072 - time_to_failure_mae: 0.0669 - val_component_failure_accuracy: 0.9573 - val_component_failure_loss: 0.1243 - val_loss: 0.6234 - val_severity_accuracy: 0.7857 - val_severity_loss: 0.4818 - val_time_to_failure_loss: 0.0058 - val_time_to_failure_mae: 0.0587 - learning_rate: 2.5000e-04
# Epoch 25/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - component_failure_accuracy: 0.9666 - component_failure_loss: 0.1030 - loss: 0.5637 - severity_accuracy: 0.8181 - severity_loss: 0.4379 - time_to_failure_loss: 0.0070 - time_to_failure_mae: 0.0661
# Epoch 25: val_loss did not improve from 0.58256
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 9s 67ms/step - component_failure_accuracy: 0.9655 - component_failure_loss: 0.1045 - loss: 0.5698 - severity_accuracy: 0.8148 - severity_loss: 0.4431 - time_to_failure_loss: 0.0069 - time_to_failure_mae: 0.0656 - val_component_failure_accuracy: 0.9566 - val_component_failure_loss: 0.1278 - val_loss: 0.6231 - val_severity_accuracy: 0.7891 - val_severity_loss: 0.4789 - val_time_to_failure_loss: 0.0056 - val_time_to_failure_mae: 0.0576 - learning_rate: 2.5000e-04
# Epoch 26/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - component_failure_accuracy: 0.9647 - component_failure_loss: 0.1039 - loss: 0.5643 - severity_accuracy: 0.8195 - severity_loss: 0.4375 - time_to_failure_loss: 0.0071 - time_to_failure_mae: 0.0660
# Epoch 26: val_loss did not improve from 0.58256
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 9s 69ms/step - component_failure_accuracy: 0.9641 - component_failure_loss: 0.1027 - loss: 0.5633 - severity_accuracy: 0.8183 - severity_loss: 0.4379 - time_to_failure_loss: 0.0071 - time_to_failure_mae: 0.0662 - val_component_failure_accuracy: 0.9579 - val_component_failure_loss: 0.1279 - val_loss: 0.6428 - val_severity_accuracy: 0.7870 - val_severity_loss: 0.4977 - val_time_to_failure_loss: 0.0061 - val_time_to_failure_mae: 0.0613 - learning_rate: 2.5000e-04
# Epoch 27/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - component_failure_accuracy: 0.9615 - component_failure_loss: 0.1076 - loss: 0.5513 - severity_accuracy: 0.8211 - severity_loss: 0.4200 - time_to_failure_loss: 0.0069 - time_to_failure_mae: 0.0655
# Epoch 27: val_loss did not improve from 0.58256
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 9s 68ms/step - component_failure_accuracy: 0.9645 - component_failure_loss: 0.1039 - loss: 0.5594 - severity_accuracy: 0.8145 - severity_loss: 0.4322 - time_to_failure_loss: 0.0069 - time_to_failure_mae: 0.0655 - val_component_failure_accuracy: 0.9559 - val_component_failure_loss: 0.1253 - val_loss: 0.6317 - val_severity_accuracy: 0.7810 - val_severity_loss: 0.4894 - val_time_to_failure_loss: 0.0057 - val_time_to_failure_mae: 0.0579 - learning_rate: 2.5000e-04
# Epoch 28/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - component_failure_accuracy: 0.9708 - component_failure_loss: 0.0851 - loss: 0.5166 - severity_accuracy: 0.8253 - severity_loss: 0.4124 - time_to_failure_loss: 0.0069 - time_to_failure_mae: 0.0655
# Epoch 28: val_loss did not improve from 0.58256
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 9s 67ms/step - component_failure_accuracy: 0.9654 - component_failure_loss: 0.0962 - loss: 0.5490 - severity_accuracy: 0.8175 - severity_loss: 0.4311 - time_to_failure_loss: 0.0070 - time_to_failure_mae: 0.0661 - val_component_failure_accuracy: 0.9566 - val_component_failure_loss: 0.1231 - val_loss: 0.6400 - val_severity_accuracy: 0.7790 - val_severity_loss: 0.4994 - val_time_to_failure_loss: 0.0058 - val_time_to_failure_mae: 0.0588 - learning_rate: 2.5000e-04
# Epoch 29/100
# 132/133 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - component_failure_accuracy: 0.9698 - component_failure_loss: 0.0950 - loss: 0.5205 - severity_accuracy: 0.8344 - severity_loss: 0.4045 - time_to_failure_loss: 0.0067 - time_to_failure_mae: 0.0643
# Epoch 29: val_loss did not improve from 0.58256
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 9s 67ms/step - component_failure_accuracy: 0.9664 - component_failure_loss: 0.0994 - loss: 0.5339 - severity_accuracy: 0.8313 - severity_loss: 0.4133 - time_to_failure_loss: 0.0068 - time_to_failure_mae: 0.0650 - val_component_failure_accuracy: 0.9539 - val_component_failure_loss: 0.1298 - val_loss: 0.6580 - val_severity_accuracy: 0.7797 - val_severity_loss: 0.5090 - val_time_to_failure_loss: 0.0060 - val_time_to_failure_mae: 0.0599 - learning_rate: 2.5000e-04
# Epoch 30/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - component_failure_accuracy: 0.9681 - component_failure_loss: 0.1057 - loss: 0.5416 - severity_accuracy: 0.8289 - severity_loss: 0.4127 - time_to_failure_loss: 0.0070 - time_to_failure_mae: 0.0657
# Epoch 30: val_loss did not improve from 0.58256
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 9s 68ms/step - component_failure_accuracy: 0.9698 - component_failure_loss: 0.0901 - loss: 0.5366 - severity_accuracy: 0.8237 - severity_loss: 0.4264 - time_to_failure_loss: 0.0071 - time_to_failure_mae: 0.0661 - val_component_failure_accuracy: 0.9579 - val_component_failure_loss: 0.1317 - val_loss: 0.6529 - val_severity_accuracy: 0.7891 - val_severity_loss: 0.5029 - val_time_to_failure_loss: 0.0057 - val_time_to_failure_mae: 0.0580 - learning_rate: 2.5000e-04
# Epoch 31/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - component_failure_accuracy: 0.9696 - component_failure_loss: 0.0820 - loss: 0.5013 - severity_accuracy: 0.8345 - severity_loss: 0.4009 - time_to_failure_loss: 0.0065 - time_to_failure_mae: 0.0640
# Epoch 31: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 31: val_loss did not improve from 0.58256
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 9s 70ms/step - component_failure_accuracy: 0.9656 - component_failure_loss: 0.0965 - loss: 0.5238 - severity_accuracy: 0.8329 - severity_loss: 0.4074 - time_to_failure_loss: 0.0067 - time_to_failure_mae: 0.0643 - val_component_failure_accuracy: 0.9593 - val_component_failure_loss: 0.1386 - val_loss: 0.6698 - val_severity_accuracy: 0.7770 - val_severity_loss: 0.5126 - val_time_to_failure_loss: 0.0061 - val_time_to_failure_mae: 0.0613 - learning_rate: 2.5000e-04
# Epoch 32/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - component_failure_accuracy: 0.9664 - component_failure_loss: 0.0977 - loss: 0.5221 - severity_accuracy: 0.8384 - severity_loss: 0.4028 - time_to_failure_loss: 0.0068 - time_to_failure_mae: 0.0651
# Epoch 32: val_loss did not improve from 0.58256
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 9s 69ms/step - component_failure_accuracy: 0.9704 - component_failure_loss: 0.0902 - loss: 0.5086 - severity_accuracy: 0.8347 - severity_loss: 0.3986 - time_to_failure_loss: 0.0068 - time_to_failure_mae: 0.0647 - val_component_failure_accuracy: 0.9579 - val_component_failure_loss: 0.1288 - val_loss: 0.6504 - val_severity_accuracy: 0.7864 - val_severity_loss: 0.5043 - val_time_to_failure_loss: 0.0057 - val_time_to_failure_mae: 0.0580 - learning_rate: 1.2500e-04
# Epoch 33/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - component_failure_accuracy: 0.9732 - component_failure_loss: 0.0751 - loss: 0.4867 - severity_accuracy: 0.8391 - severity_loss: 0.3947 - time_to_failure_loss: 0.0063 - time_to_failure_mae: 0.0625
# Epoch 33: val_loss did not improve from 0.58256
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 9s 67ms/step - component_failure_accuracy: 0.9714 - component_failure_loss: 0.0809 - loss: 0.4922 - severity_accuracy: 0.8408 - severity_loss: 0.3940 - time_to_failure_loss: 0.0065 - time_to_failure_mae: 0.0635 - val_component_failure_accuracy: 0.9586 - val_component_failure_loss: 0.1374 - val_loss: 0.6687 - val_severity_accuracy: 0.7824 - val_severity_loss: 0.5127 - val_time_to_failure_loss: 0.0058 - val_time_to_failure_mae: 0.0586 - learning_rate: 1.2500e-04
# Epoch 34/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - component_failure_accuracy: 0.9730 - component_failure_loss: 0.0868 - loss: 0.5093 - severity_accuracy: 0.8322 - severity_loss: 0.4033 - time_to_failure_loss: 0.0064 - time_to_failure_mae: 0.0625
# Epoch 34: val_loss did not improve from 0.58256
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 9s 67ms/step - component_failure_accuracy: 0.9720 - component_failure_loss: 0.0823 - loss: 0.4971 - severity_accuracy: 0.8360 - severity_loss: 0.3964 - time_to_failure_loss: 0.0065 - time_to_failure_mae: 0.0631 - val_component_failure_accuracy: 0.9566 - val_component_failure_loss: 0.1415 - val_loss: 0.6831 - val_severity_accuracy: 0.7790 - val_severity_loss: 0.5215 - val_time_to_failure_loss: 0.0061 - val_time_to_failure_mae: 0.0602 - learning_rate: 1.2500e-04
# Epoch 35/100
# 132/133 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - component_failure_accuracy: 0.9705 - component_failure_loss: 0.0838 - loss: 0.4962 - severity_accuracy: 0.8399 - severity_loss: 0.3937 - time_to_failure_loss: 0.0066 - time_to_failure_mae: 0.0640
# Epoch 35: val_loss did not improve from 0.58256
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 9s 67ms/step - component_failure_accuracy: 0.9720 - component_failure_loss: 0.0797 - loss: 0.4867 - severity_accuracy: 0.8379 - severity_loss: 0.3889 - time_to_failure_loss: 0.0066 - time_to_failure_mae: 0.0641 - val_component_failure_accuracy: 0.9579 - val_component_failure_loss: 0.1435 - val_loss: 0.6857 - val_severity_accuracy: 0.7757 - val_severity_loss: 0.5221 - val_time_to_failure_loss: 0.0059 - val_time_to_failure_mae: 0.0594 - learning_rate: 1.2500e-04
# Epoch 35: early stopping
# Restoring model weights from the end of the best epoch: 15.
#
# [SUCCESS] Training completed!
#
# [SUCCESS] Training completed!

# %%
print("\n[INFO] Evaluating model on test set...")

# Evaluate
test_results = model.evaluate(
    X_test,
    {
        'component_failure': y_comp_test,
        'time_to_failure': y_time_test,
        'severity': y_sev_test
    },
    verbose=0
)

print("\n" + "=" * 80)
print("TEST SET RESULTS")
print("=" * 80)
print(f"Total Loss: {test_results[0]:.4f}")
print(f"Component Failure Loss: {test_results[1]:.4f}")
print(f"Time to Failure Loss: {test_results[2]:.4f}")
print(f"Severity Loss: {test_results[3]:.4f}")
print(f"\n>>> Component Failure Accuracy: {test_results[4]*100:.2f}%")
print(f">>> Time to Failure MAE: {test_results[5]:.4f} (normalized)")
# Out:
# [INFO] Evaluating model on test set...
#
# ================================================================================
# TEST SET RESULTS
# ================================================================================
# Total Loss: 0.5826
# Component Failure Loss: 0.1040
# Time to Failure Loss: 0.0054
# Severity Loss: 0.4577
#
# >>> Component Failure Accuracy: 96.33%
# >>> Time to Failure MAE: 0.7944 (normalized)

# %%
print("\n[INFO] Performing detailed analysis...")

# Get predictions
predictions = model.predict(X_test)
pred_components = np.argmax(predictions[0], axis=1)
pred_severity = np.argmax(predictions[2], axis=1)

# Per-class accuracy
from sklearn.metrics import classification_report, confusion_matrix

components = ['engine', 'transmission', 'brakes', 'battery', 'cooling_system']
severities = ['low', 'medium', 'high', 'critical']

print("\n" + "=" * 80)
print("COMPONENT FAILURE - DETAILED METRICS")
print("=" * 80)
print(classification_report(y_comp_test, pred_components, target_names=components))

print("\n" + "=" * 80)
print("SEVERITY - DETAILED METRICS")
print("=" * 80)
print(classification_report(y_sev_test, pred_severity, target_names=severities))
# Out:
# [INFO] Performing detailed analysis...
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step
#
# ================================================================================
# COMPONENT FAILURE - DETAILED METRICS
# ================================================================================
#                 precision    recall  f1-score   support
#
#         engine       0.98      0.97      0.97       291
#   transmission       0.97      0.96      0.96       304
#         brakes       0.94      0.93      0.94       303
#        battery       0.94      0.98      0.96       296
# cooling_system       0.98      0.98      0.98       304
#
#       accuracy                           0.96      1498
#      macro avg       0.96      0.96      0.96      1498
#   weighted avg       0.96      0.96      0.96      1498
#
#
# ================================================================================
# SEVERITY - DETAILED METRICS
# ================================================================================
#               precision    recall  f1-score   support
#
#          low       0.00      0.00      0.00        10
#       medium       0.67      0.56      0.61       173
#         high       0.76      0.74      0.75       597
#     critical       0.85      0.91      0.88       718
#
#     accuracy                           0.79      1498
#    macro avg       0.57      0.55      0.56      1498
# weighted avg       0.78      0.79      0.79      1498
# /home/praneeth-yeddu/anaconda3/envs/ey2/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /home/praneeth-yeddu/anaconda3/envs/ey2/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /home/praneeth-yeddu/anaconda3/envs/ey2/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])

# %%
print("\n[INFO] Saving model and metadata...")

# Save final model
model.save('weights_and_metadata/vehicle_failure_lstm_optimized.keras')
print("[SUCCESS] Saved model to 'weights_and_metadata/vehicle_failure_lstm_optimized.keras'")

# Save model weights
model.save_weights('vehicle_failure_model.h5')
print("[SUCCESS] Saved weights to 'weights_and_metadata/vehicle_failure_model.h5'")



# Save metadata
metadata = {
    'num_samples': len(df),
    'num_sequences': len(X_sequences),
    'sequence_length': sequence_length,
    'num_features': len(feature_columns),
    'feature_columns': feature_columns,
    'components': components,
    'severities': severities,
    'train_samples': len(X_train),
    'test_samples': len(X_test),
    'model_params': int(model.count_params()),
    'final_metrics': {
        'test_loss': float(test_results[0]),
        'component_accuracy': float(test_results[4]),
        'time_mae': float(test_results[5]),
        'severity_accuracy': float(test_results[6])
    }
}

with open('weights_and_metadata/model_metadata_optimized.json', 'w') as f:
    json.dump(metadata, f, indent=2)
print("[SUCCESS] Saved metadata to 'weights_and_metadata/model_metadata_optimized.json'")
# Out:
# [INFO] Saving model and metadata...
# [SUCCESS] Saved model to 'weights_and_metadata/vehicle_failure_lstm_optimized.keras'
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[28], line 8
#       5 print("[SUCCESS] Saved model to 'weights_and_metadata/vehicle_failure_lstm_optimized.keras'")
#       7 # Save model weights
# ----> 8 model.save_weights('vehicle_failure_model.h5')
#       9 print("[SUCCESS] Saved weights to 'weights_and_metadata/vehicle_failure_model.h5'")
#      13 # Save metadata
#
# File ~/anaconda3/envs/ey2/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File ~/anaconda3/envs/ey2/lib/python3.10/site-packages/keras/src/saving/saving_api.py:230, in save_weights(model, filepath, overwrite, max_shard_size, **kwargs)
#     228 filepath_str = str(filepath)
#     229 if max_shard_size is None and not filepath_str.endswith(".weights.h5"):
# --> 230     raise ValueError(
#     231         "The filename must end in `.weights.h5`. "
#     232         f"Received: filepath={filepath_str}"
#     233     )
#     234 elif max_shard_size is not None and not filepath_str.endswith(
#     235     ("weights.h5", "weights.json")
#     236 ):
#     237     raise ValueError(
#     238         "The filename must end in `.weights.json` when `max_shard_size` is "
#     239         f"specified. Received: filepath={filepath_str}"
#     240     )
#
# ValueError: The filename must end in `.weights.h5`. Received: filepath=vehicle_failure_model.h5
